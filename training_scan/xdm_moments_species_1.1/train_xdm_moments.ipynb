# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002
# Out:
# /home/joaomorado/micromamba/envs/fes-ml-aev/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")

# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha, m1):
    """XDM C6 coefficient calculation for homoatomic case."""
    return alpha * m1 / 2.0


def c8(alpha, m2):
    """XDM C8 coefficient calculation for homoatomic case."""
    return alpha * m2 * 3 / 2.0


def c10(alpha, m1, m2, m3):
    """XDM C10 coefficient calculation for homoatomic case."""
    return 2.0 * alpha * m3 + 21 / 10 * alpha * m2**2 / (m1 + 1e-16)

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_species_iter2.mat",
    alpha_mode="species",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, _, alpha_unscreened, *_ = emle_base(
    species_ds, xyz_ds, q_mol
)
s = s.detach()
q_core = q_core.detach()
q_val = q_val.detach()
A_thole = A_thole.detach()
alpha = emle_base.get_isotropic_polarizabilities_thole(A_thole)
alpha = alpha.detach() * (species_ds > 0)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, m1_ds)
c8_train = c8(alpha, m2_ds)
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds)

# Setup grid
n = 1000
r_start = 1.1
rij_scale = torch.linspace(r_start, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate dispersion energy
Eij = -(
    c6_train[..., None] / (rij**6 + 1e-16)
    + c8_train[..., None] / (rij**8 + 1e-16)
    + c10_train[..., None] / (rij**10 + 1e-16)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 1000
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, m1_eff).abs()
    Eij_opt = -c6_opt[..., None] / (rij**6 + 1e-16)
    delta = Eij_opt - Eij
    loss = torch.mean(delta[mask] ** 2) / torch.var(Eij[mask])
    loss.backward(retain_graph=True)
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.24905513226985931
# Epoch 50, Loss: 0.021086907014250755
# Epoch 100, Loss: 0.011359707452356815
# Epoch 150, Loss: 0.009805743582546711
# Epoch 200, Loss: 0.009579298086464405
# Epoch 250, Loss: 0.00955875776708126
# Epoch 300, Loss: 0.009557613171637058
# Epoch 350, Loss: 0.009557574987411499
# Epoch 400, Loss: 0.009557574987411499
# Epoch 450, Loss: 0.009557574987411499
# Epoch 500, Loss: 0.009557574987411499
# Epoch 550, Loss: 0.009557574987411499
# Epoch 600, Loss: 0.009557574987411499
# Epoch 650, Loss: 0.009557574987411499
# Epoch 700, Loss: 0.009557574987411499
# Epoch 750, Loss: 0.009557574987411499
# Epoch 800, Loss: 0.009557574987411499
# Epoch 850, Loss: 0.009557574987411499
# Epoch 900, Loss: 0.009557574987411499
# Epoch 950, Loss: 0.009557574987411499

# %%
# Compute ratios
c6_optimized = c6(alpha, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel(r"$\langle M_1^2 \rangle_{eff}  / \langle M_1^2 \rangle_{XDM}$")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]


def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]


xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %%
species = scipy.io.loadmat("../../emle_models/ligand_patched_species_iter2.mat")
reference = scipy.io.loadmat("../../emle_models/ligand_patched_reference_iter2.mat")

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-2,
    epochs=1500,
    emle_model="../../emle_models/ligand_patched_species_iter2.mat",
    plot_data_filename=plot_data_filename,
    model_filename=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    l2_reg_c6=1e-3,
    alpha_mode="species",
)
# Out:
# 2025-12-19 15:47:44.563 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_species_iter2.mat'
# 2025-12-19 15:47:44.579 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2025-12-19 15:47:45.522 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 10: Loss =  30.0389    RMSE =   5.4808    Max Error =  21.8459
# 2025-12-19 15:47:46.402 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 20: Loss =  26.6697    RMSE =   5.1643    Max Error =  21.6603
# 2025-12-19 15:47:47.286 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 30: Loss =  22.7920    RMSE =   4.7741    Max Error =  21.5553
# 2025-12-19 15:47:48.165 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 40: Loss =  18.5763    RMSE =   4.3100    Max Error =  21.4500
# 2025-12-19 15:47:49.043 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 50: Loss =  14.4412    RMSE =   3.8001    Max Error =  21.3432
# 2025-12-19 15:47:49.921 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 60: Loss =  10.8875    RMSE =   3.2996    Max Error =  21.2321
# 2025-12-19 15:47:50.798 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 70: Loss =   8.1482    RMSE =   2.8545    Max Error =  21.1114
# 2025-12-19 15:47:51.675 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 80: Loss =   6.1047    RMSE =   2.4707    Max Error =  20.9780
# 2025-12-19 15:47:52.553 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 90: Loss =   4.5511    RMSE =   2.1332    Max Error =  20.8235
# 2025-12-19 15:47:53.429 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 100: Loss =   3.3841    RMSE =   1.8395    Max Error =  20.6616
# 2025-12-19 15:47:54.305 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 110: Loss =   2.5359    RMSE =   1.5923    Max Error =  20.4040
# 2025-12-19 15:47:55.183 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 120: Loss =   1.9213    RMSE =   1.3859    Max Error =  19.9291
# 2025-12-19 15:47:56.060 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 130: Loss =   1.4712    RMSE =   1.2127    Max Error =  19.1462
# 2025-12-19 15:47:56.937 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 140: Loss =   1.1438    RMSE =   1.0692    Max Error =  18.0459
# 2025-12-19 15:47:57.814 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 150: Loss =   0.9089    RMSE =   0.9531    Max Error =  16.7953
# 2025-12-19 15:47:58.691 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 160: Loss =   0.7399    RMSE =   0.8598    Max Error =  15.6654
# 2025-12-19 15:47:59.570 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 170: Loss =   0.6158    RMSE =   0.7844    Max Error =  14.5413
# 2025-12-19 15:48:00.449 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 180: Loss =   0.5222    RMSE =   0.7223    Max Error =  13.4694
# 2025-12-19 15:48:01.326 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 190: Loss =   0.4496    RMSE =   0.6701    Max Error =  12.4784
# 2025-12-19 15:48:02.204 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 200: Loss =   0.3917    RMSE =   0.6254    Max Error =  11.5801
# 2025-12-19 15:48:03.081 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 210: Loss =   0.3444    RMSE =   0.5863    Max Error =  10.7736
# 2025-12-19 15:48:03.960 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 220: Loss =   0.3049    RMSE =   0.5517    Max Error =  10.0497
# 2025-12-19 15:48:04.837 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 230: Loss =   0.2715    RMSE =   0.5205    Max Error =   9.3960
# 2025-12-19 15:48:05.721 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 240: Loss =   0.2429    RMSE =   0.4922    Max Error =   8.8005
# 2025-12-19 15:48:06.599 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 250: Loss =   0.2181    RMSE =   0.4664    Max Error =   8.2530
# 2025-12-19 15:48:07.477 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 260: Loss =   0.1965    RMSE =   0.4425    Max Error =   7.7457
# 2025-12-19 15:48:08.353 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.1774    RMSE =   0.4205    Max Error =   7.2729
# 2025-12-19 15:48:09.229 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.1606    RMSE =   0.4000    Max Error =   6.8304
# 2025-12-19 15:48:10.107 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.1456    RMSE =   0.3808    Max Error =   6.4153
# 2025-12-19 15:48:10.984 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.1323    RMSE =   0.3628    Max Error =   6.0250
# 2025-12-19 15:48:11.857 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.1203    RMSE =   0.3459    Max Error =   5.6574
# 2025-12-19 15:48:12.730 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.1095    RMSE =   0.3300    Max Error =   5.3109
# 2025-12-19 15:48:13.608 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.0999    RMSE =   0.3151    Max Error =   4.9837
# 2025-12-19 15:48:14.484 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.0912    RMSE =   0.3010    Max Error =   4.8301
# 2025-12-19 15:48:15.361 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.0834    RMSE =   0.2877    Max Error =   4.7628
# 2025-12-19 15:48:16.237 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.0764    RMSE =   0.2753    Max Error =   4.6931
# 2025-12-19 15:48:17.116 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.0701    RMSE =   0.2636    Max Error =   4.6210
# 2025-12-19 15:48:17.993 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.0645    RMSE =   0.2527    Max Error =   4.5467
# 2025-12-19 15:48:18.871 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.0594    RMSE =   0.2425    Max Error =   4.4701
# 2025-12-19 15:48:19.749 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0549    RMSE =   0.2330    Max Error =   4.3915
# 2025-12-19 15:48:20.627 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0509    RMSE =   0.2242    Max Error =   4.3108
# 2025-12-19 15:48:21.503 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0473    RMSE =   0.2161    Max Error =   4.2282
# 2025-12-19 15:48:22.384 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0442    RMSE =   0.2086    Max Error =   4.1439
# 2025-12-19 15:48:23.266 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0413    RMSE =   0.2018    Max Error =   4.0579
# 2025-12-19 15:48:24.149 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0388    RMSE =   0.1955    Max Error =   3.9704
# 2025-12-19 15:48:25.034 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0366    RMSE =   0.1897    Max Error =   3.8816
# 2025-12-19 15:48:25.916 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0347    RMSE =   0.1845    Max Error =   3.7915
# 2025-12-19 15:48:26.799 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0330    RMSE =   0.1798    Max Error =   3.7004
# 2025-12-19 15:48:27.683 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0314    RMSE =   0.1755    Max Error =   3.6085
# 2025-12-19 15:48:28.564 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0301    RMSE =   0.1715    Max Error =   3.5158
# 2025-12-19 15:48:29.446 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0289    RMSE =   0.1680    Max Error =   3.4225
# 2025-12-19 15:48:30.327 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0278    RMSE =   0.1648    Max Error =   3.3288
# 2025-12-19 15:48:31.210 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0268    RMSE =   0.1619    Max Error =   3.2349
# 2025-12-19 15:48:32.092 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0260    RMSE =   0.1593    Max Error =   3.1409
# 2025-12-19 15:48:32.975 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0253    RMSE =   0.1569    Max Error =   3.0470
# 2025-12-19 15:48:33.859 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0246    RMSE =   0.1547    Max Error =   2.9533
# 2025-12-19 15:48:34.741 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0240    RMSE =   0.1528    Max Error =   2.8600
# 2025-12-19 15:48:35.621 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0235    RMSE =   0.1510    Max Error =   2.7672
# 2025-12-19 15:48:36.504 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0230    RMSE =   0.1495    Max Error =   2.6751
# 2025-12-19 15:48:37.393 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0225    RMSE =   0.1480    Max Error =   2.5838
# 2025-12-19 15:48:38.276 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0222    RMSE =   0.1467    Max Error =   2.4935
# 2025-12-19 15:48:39.157 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0218    RMSE =   0.1455    Max Error =   2.4042
# 2025-12-19 15:48:40.039 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0215    RMSE =   0.1445    Max Error =   2.3162
# 2025-12-19 15:48:40.922 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0212    RMSE =   0.1435    Max Error =   2.2295
# 2025-12-19 15:48:41.805 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0210    RMSE =   0.1426    Max Error =   2.1441
# 2025-12-19 15:48:42.686 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0208    RMSE =   0.1418    Max Error =   2.0604
# 2025-12-19 15:48:43.569 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0205    RMSE =   0.1411    Max Error =   1.9782
# 2025-12-19 15:48:44.449 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0204    RMSE =   0.1404    Max Error =   1.8977
# 2025-12-19 15:48:45.331 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0202    RMSE =   0.1399    Max Error =   1.8191
# 2025-12-19 15:48:46.212 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0201    RMSE =   0.1393    Max Error =   1.7423
# 2025-12-19 15:48:47.095 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0199    RMSE =   0.1388    Max Error =   1.6674
# 2025-12-19 15:48:47.980 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0198    RMSE =   0.1384    Max Error =   1.5944
# 2025-12-19 15:48:48.863 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0197    RMSE =   0.1380    Max Error =   1.5235
# 2025-12-19 15:48:49.744 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0196    RMSE =   0.1377    Max Error =   1.4547
# 2025-12-19 15:48:50.627 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0195    RMSE =   0.1374    Max Error =   1.3879
# 2025-12-19 15:48:51.510 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0194    RMSE =   0.1371    Max Error =   1.3232
# 2025-12-19 15:48:52.395 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0194    RMSE =   0.1368    Max Error =   1.2607
# 2025-12-19 15:48:53.276 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0193    RMSE =   0.1366    Max Error =   1.2003
# 2025-12-19 15:48:54.158 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0192    RMSE =   0.1364    Max Error =   1.1420
# 2025-12-19 15:48:55.041 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0192    RMSE =   0.1362    Max Error =   1.0858
# 2025-12-19 15:48:55.924 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0191    RMSE =   0.1360    Max Error =   1.0318
# 2025-12-19 15:48:56.805 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0191    RMSE =   0.1359    Max Error =   0.9798
# 2025-12-19 15:48:57.691 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0191    RMSE =   0.1358    Max Error =   0.9300
# 2025-12-19 15:48:58.573 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 840: Loss =   0.0190    RMSE =   0.1356    Max Error =   0.8822
# 2025-12-19 15:48:59.455 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 850: Loss =   0.0190    RMSE =   0.1355    Max Error =   0.8779
# 2025-12-19 15:49:00.336 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 860: Loss =   0.0190    RMSE =   0.1354    Max Error =   0.8786
# 2025-12-19 15:49:01.217 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 870: Loss =   0.0190    RMSE =   0.1354    Max Error =   0.8792
# 2025-12-19 15:49:02.098 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 880: Loss =   0.0189    RMSE =   0.1353    Max Error =   0.8797
# 2025-12-19 15:49:02.980 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 890: Loss =   0.0189    RMSE =   0.1352    Max Error =   0.8803
# 2025-12-19 15:49:03.861 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 900: Loss =   0.0189    RMSE =   0.1352    Max Error =   0.8808
# 2025-12-19 15:49:04.743 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 910: Loss =   0.0189    RMSE =   0.1351    Max Error =   0.8813
# 2025-12-19 15:49:05.625 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 920: Loss =   0.0189    RMSE =   0.1351    Max Error =   0.8817
# 2025-12-19 15:49:06.507 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 930: Loss =   0.0189    RMSE =   0.1350    Max Error =   0.8821
# 2025-12-19 15:49:07.389 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 940: Loss =   0.0189    RMSE =   0.1350    Max Error =   0.8825
# 2025-12-19 15:49:08.270 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 950: Loss =   0.0189    RMSE =   0.1350    Max Error =   0.8829
# 2025-12-19 15:49:09.152 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 960: Loss =   0.0189    RMSE =   0.1349    Max Error =   0.8832
# 2025-12-19 15:49:10.037 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 970: Loss =   0.0188    RMSE =   0.1349    Max Error =   0.8835
# 2025-12-19 15:49:10.918 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 980: Loss =   0.0188    RMSE =   0.1349    Max Error =   0.8838
# 2025-12-19 15:49:11.800 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 990: Loss =   0.0188    RMSE =   0.1349    Max Error =   0.8841
# 2025-12-19 15:49:12.682 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1000: Loss =   0.0188    RMSE =   0.1349    Max Error =   0.8843
# 2025-12-19 15:49:13.563 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1010: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8845
# 2025-12-19 15:49:14.444 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1020: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8848
# 2025-12-19 15:49:15.326 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1030: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8850
# 2025-12-19 15:49:16.207 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1040: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8851
# 2025-12-19 15:49:17.088 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1050: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8853
# 2025-12-19 15:49:17.970 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1060: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8855
# 2025-12-19 15:49:18.852 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1070: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8856
# 2025-12-19 15:49:19.734 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1080: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8857
# 2025-12-19 15:49:20.616 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1090: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8859
# 2025-12-19 15:49:21.497 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1100: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8860
# 2025-12-19 15:49:22.378 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1110: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8861
# 2025-12-19 15:49:23.260 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1120: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8862
# 2025-12-19 15:49:24.142 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1130: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8862
# 2025-12-19 15:49:25.024 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1140: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8863
# 2025-12-19 15:49:25.906 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1150: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8864
# 2025-12-19 15:49:26.788 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1160: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8865
# 2025-12-19 15:49:27.670 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1170: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8865
# 2025-12-19 15:49:28.551 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1180: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8866
# 2025-12-19 15:49:29.433 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1190: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8866
# 2025-12-19 15:49:30.315 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1200: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8867
# 2025-12-19 15:49:31.197 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1210: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8867
# 2025-12-19 15:49:32.078 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1220: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8867
# 2025-12-19 15:49:32.960 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1230: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8868
# 2025-12-19 15:49:33.841 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1240: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8868
# 2025-12-19 15:49:34.723 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1250: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8868
# 2025-12-19 15:49:35.606 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1260: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8869
# 2025-12-19 15:49:36.489 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1270: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8869
# 2025-12-19 15:49:37.371 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1280: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8869
# 2025-12-19 15:49:38.254 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1290: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8869
# 2025-12-19 15:49:39.136 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1300: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8869
# 2025-12-19 15:49:40.018 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1310: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:40.901 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1320: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:41.786 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1330: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:42.667 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1340: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:43.549 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1350: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:44.430 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1360: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:45.311 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1370: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:46.191 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1380: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:47.073 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1390: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:47.955 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1400: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:48.838 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1410: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:49.719 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1420: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:50.601 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1430: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8870
# 2025-12-19 15:49:51.485 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1440: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# 2025-12-19 15:49:52.367 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1450: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# 2025-12-19 15:49:53.249 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1460: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# 2025-12-19 15:49:54.132 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1470: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# 2025-12-19 15:49:55.015 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1480: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# 2025-12-19 15:49:55.898 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1490: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# 2025-12-19 15:49:56.780 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1500: Loss =   0.0188    RMSE =   0.1348    Max Error =   0.8871
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]

for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    lims = [0, training_results["c6_qm"][training_results["c6_qm"] > 0].max() * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
import re

from openff.toolkit import ForceField
from openff.units import unit as off_unit
from openmm import unit


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
# rmin = rmin2_ref[species_ds] * vol_ratio**(1/3) * 2
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data / off_val, bins=100, kde=True, ax=ax, linewidth=0)

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6^{EMLE} / C_6^{OpenFF-2.0.0}$")
    ax.set_ylabel("Frequency")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
from openff.toolkit import ForceField, Molecule, Topology
from openff.units import unit

ff = ForceField("openff-2.0.0.offxml")
mol = Molecule.from_smiles("C1CCCCC1")
mol.generate_conformers(n_conformers=1)
topology_off = Topology.from_molecules([mol])

xyz_chx = torch.tensor(
    mol.conformers[0].m_as(unit.bohr).astype(np.float32),
    dtype=torch.float32,
    device=device,
).unsqueeze(0)
species_chx = torch.tensor(
    [atom.atomic_number for atom in mol.atoms], dtype=torch.long, device=device
).unsqueeze(0)
q_mol = torch.zeros(xyz_chx.shape[0], device=device, dtype=dtype)

# Get <M_1^2>eff and A_thole for cyclohexane
s, q_core, q_val, A_thole, c6_chx, *_ = emle_base.forward(
    species_chx,
    xyz_chx.to(torch.float32),
    q_mol,
    calc_A_thole=True,
    calc_c6=True,
)

# Get isotropic polarizabilities
alpha_chx = emle_base.get_isotropic_polarizabilities_thole(A_thole)

# Get LJ parameters
c6_chx = 0.5 * c6_chx * alpha_chx
radius = 2.54 * alpha_chx ** (1 / 7)
rmin = 2 * radius
sigma_qm = rmin / (2 ** (1.0 / 6.0))
epsilon_qm = c6_chx / (2 * rmin**6.0)

# Convert units
sigma_qm = sigma_qm / (ANGSTROM_TO_BOHR) * 10
epsilon_qm = epsilon_qm * HARTREE_TO_KJ_MOL / 4.184
q_net = q_core + q_val
c6 = 4 * epsilon_qm * (sigma_qm**6)

# Print table
print(
    f"{'Atom':<6} {'Sigma (A)':<15} {'Epsilon (kcal/mol)':<20} {'Q_core (e)':<10} {'Q_val (e)':<10} {'Q_net (e)':<10}"
)
for i, atom in enumerate(mol.atoms):
    print(
        f"{atom.symbol:<6} {sigma_qm[0, i].item() * 0.1:<15.6f} {epsilon_qm[0, i].item():<20.6f} {q_core[0, i].item():<10.6f} {q_val[0, i].item():<10.6f} {q_net[0, i].item():<10.6f}"
    )
# Out:
# Atom   Sigma (A)       Epsilon (kcal/mol)   Q_core (e) Q_val (e)  Q_net (e)
# C      3.438046        0.105342             4.350801   -4.423770  -0.072969
# C      3.439973        0.105656             4.350801   -4.433394  -0.082593
# C      3.438678        0.105544             4.350801   -4.429653  -0.078852
# C      3.436710        0.105312             4.350801   -4.429975  -0.079174
# C      3.438747        0.105501             4.350801   -4.432225  -0.081424
# C      3.440240        0.105648             4.350801   -4.429902  -0.079101
# H      2.697966        0.015908             1.000000   -0.968298  0.031702
# H      2.697857        0.016059             1.000000   -0.968221  0.031779
# H      2.688442        0.015412             1.000000   -0.954841  0.045159
# H      2.673229        0.015026             1.000000   -0.953087  0.046913
# H      2.704401        0.016048             1.000000   -0.965704  0.034296
# H      2.683044        0.015506             1.000000   -0.961162  0.038838
# H      2.678925        0.015255             1.000000   -0.957034  0.042966
# H      2.696840        0.015718             1.000000   -0.959885  0.040115
# H      2.687638        0.015410             1.000000   -0.956156  0.043844
# H      2.677394        0.015163             1.000000   -0.954789  0.045211
# H      2.690770        0.015831             1.000000   -0.962857  0.037143
# H      2.695504        0.015776             1.000000   -0.963853  0.036147
