# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002
# Out:
# /home/joaomorado/micromamba/envs/fes-ml-aev/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")

# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha, m1):
    """XDM C6 coefficient calculation for homoatomic case."""
    return alpha * m1 / 2.0


def c8(alpha, m2):
    """XDM C8 coefficient calculation for homoatomic case."""
    return alpha * m2 * 3 / 2.0


def c10(alpha, m1, m2, m3):
    """XDM C10 coefficient calculation for homoatomic case."""
    return 2.0 * alpha * m3 + 21 / 10 * alpha * m2**2 / (m1 + 1e-16)

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_species_iter2.mat",
    alpha_mode="species",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, _, alpha_unscreened, *_ = emle_base(
    species_ds, xyz_ds, q_mol
)
s = s.detach()
q_core = q_core.detach()
q_val = q_val.detach()
A_thole = A_thole.detach()
alpha = emle_base.get_isotropic_polarizabilities_thole(A_thole)
alpha = alpha.detach() * (species_ds > 0)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, m1_ds)
c8_train = c8(alpha, m2_ds)
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds)

# Setup grid
n = 1000
r_start = 1.15
rij_scale = torch.linspace(r_start, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate dispersion energy
Eij = -(
    c6_train[..., None] / (rij**6 + 1e-16)
    + c8_train[..., None] / (rij**8 + 1e-16)
    + c10_train[..., None] / (rij**10 + 1e-16)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 1000
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, m1_eff).abs()
    Eij_opt = -c6_opt[..., None] / (rij**6 + 1e-16)
    delta = Eij_opt - Eij
    loss = torch.mean(delta[mask] ** 2) / torch.var(Eij[mask])
    loss.backward(retain_graph=True)
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.22059039771556854
# Epoch 50, Loss: 0.015322423540055752
# Epoch 100, Loss: 0.009203138761222363
# Epoch 150, Loss: 0.008340307511389256
# Epoch 200, Loss: 0.008266403339803219
# Epoch 250, Loss: 0.008263194933533669
# Epoch 300, Loss: 0.00826313067227602
# Epoch 350, Loss: 0.00826312880963087
# Epoch 400, Loss: 0.00826312880963087
# Epoch 450, Loss: 0.00826312880963087
# Epoch 500, Loss: 0.00826312880963087
# Epoch 550, Loss: 0.00826312880963087
# Epoch 600, Loss: 0.00826312880963087
# Epoch 650, Loss: 0.00826312880963087
# Epoch 700, Loss: 0.00826312880963087
# Epoch 750, Loss: 0.00826312880963087
# Epoch 800, Loss: 0.00826312880963087
# Epoch 850, Loss: 0.00826312880963087
# Epoch 900, Loss: 0.00826312880963087
# Epoch 950, Loss: 0.00826312880963087

# %%
# Compute ratios
c6_optimized = c6(alpha, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel(r"$\langle M_1^2 \rangle_{eff}  / \langle M_1^2 \rangle_{XDM}$")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]


def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]


xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %%
species = scipy.io.loadmat("../../emle_models/ligand_patched_species_iter2.mat")
reference = scipy.io.loadmat("../../emle_models/ligand_patched_reference_iter2.mat")

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-2,
    epochs=1500,
    emle_model="../../emle_models/ligand_patched_species_iter2.mat",
    plot_data_filename=plot_data_filename,
    model_filename=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    l2_reg_c6=1e-3,
    alpha_mode="species",
)
# Out:
# 2025-12-19 16:05:49.611 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_species_iter2.mat'
# 2025-12-19 16:05:49.626 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2025-12-19 16:05:50.591 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 10: Loss =  26.3262    RMSE =   5.1309    Max Error =  20.8952
# 2025-12-19 16:05:51.471 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 20: Loss =  23.2213    RMSE =   4.8188    Max Error =  21.0044
# 2025-12-19 16:05:52.351 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 30: Loss =  19.6565    RMSE =   4.4336    Max Error =  21.1390
# 2025-12-19 16:05:53.232 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 40: Loss =  15.8387    RMSE =   3.9798    Max Error =  21.2909
# 2025-12-19 16:05:54.116 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 50: Loss =  12.1631    RMSE =   3.4875    Max Error =  21.4472
# 2025-12-19 16:05:55.009 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 60: Loss =   9.0690    RMSE =   3.0114    Max Error =  21.5920
# 2025-12-19 16:05:55.891 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 70: Loss =   6.7145    RMSE =   2.5912    Max Error =  21.7086
# 2025-12-19 16:05:56.772 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 80: Loss =   4.9637    RMSE =   2.2279    Max Error =  21.7844
# 2025-12-19 16:05:57.651 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 90: Loss =   3.6438    RMSE =   1.9088    Max Error =  21.8162
# 2025-12-19 16:05:58.533 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 100: Loss =   2.6717    RMSE =   1.6344    Max Error =  21.8183
# 2025-12-19 16:05:59.414 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 110: Loss =   1.9796    RMSE =   1.4068    Max Error =  21.8184
# 2025-12-19 16:06:00.296 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 120: Loss =   1.4873    RMSE =   1.2193    Max Error =  21.8055
# 2025-12-19 16:06:01.175 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 130: Loss =   1.1343    RMSE =   1.0648    Max Error =  21.6478
# 2025-12-19 16:06:02.057 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 140: Loss =   0.8834    RMSE =   0.9396    Max Error =  21.1635
# 2025-12-19 16:06:02.938 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 150: Loss =   0.7064    RMSE =   0.8401    Max Error =  20.7719
# 2025-12-19 16:06:03.820 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 160: Loss =   0.5798    RMSE =   0.7611    Max Error =  20.2578
# 2025-12-19 16:06:04.700 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 170: Loss =   0.4868    RMSE =   0.6973    Max Error =  19.5630
# 2025-12-19 16:06:05.582 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 180: Loss =   0.4160    RMSE =   0.6446    Max Error =  18.7429
# 2025-12-19 16:06:06.463 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 190: Loss =   0.3604    RMSE =   0.5999    Max Error =  17.8505
# 2025-12-19 16:06:07.345 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 200: Loss =   0.3154    RMSE =   0.5611    Max Error =  16.9266
# 2025-12-19 16:06:08.227 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 210: Loss =   0.2781    RMSE =   0.5268    Max Error =  15.9966
# 2025-12-19 16:06:09.107 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 220: Loss =   0.2466    RMSE =   0.4960    Max Error =  15.0739
# 2025-12-19 16:06:09.988 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 230: Loss =   0.2197    RMSE =   0.4681    Max Error =  14.1649
# 2025-12-19 16:06:10.869 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 240: Loss =   0.1965    RMSE =   0.4426    Max Error =  13.2730
# 2025-12-19 16:06:11.754 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 250: Loss =   0.1762    RMSE =   0.4191    Max Error =  12.4014
# 2025-12-19 16:06:12.640 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 260: Loss =   0.1585    RMSE =   0.3973    Max Error =  11.5534
# 2025-12-19 16:06:13.522 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.1428    RMSE =   0.3771    Max Error =  10.7329
# 2025-12-19 16:06:14.404 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.1288    RMSE =   0.3581    Max Error =   9.9435
# 2025-12-19 16:06:15.285 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.1164    RMSE =   0.3404    Max Error =   9.1879
# 2025-12-19 16:06:16.167 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.1054    RMSE =   0.3237    Max Error =   8.4683
# 2025-12-19 16:06:17.046 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.0955    RMSE =   0.3081    Max Error =   7.7861
# 2025-12-19 16:06:17.929 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.0866    RMSE =   0.2933    Max Error =   7.1418
# 2025-12-19 16:06:18.811 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.0787    RMSE =   0.2795    Max Error =   6.5358
# 2025-12-19 16:06:19.693 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.0716    RMSE =   0.2665    Max Error =   5.9679
# 2025-12-19 16:06:20.575 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.0653    RMSE =   0.2544    Max Error =   5.4376
# 2025-12-19 16:06:21.458 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.0596    RMSE =   0.2430    Max Error =   4.9442
# 2025-12-19 16:06:22.336 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.0546    RMSE =   0.2324    Max Error =   4.4867
# 2025-12-19 16:06:23.219 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.0501    RMSE =   0.2225    Max Error =   4.0640
# 2025-12-19 16:06:24.103 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.0461    RMSE =   0.2134    Max Error =   3.6747
# 2025-12-19 16:06:24.986 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0426    RMSE =   0.2049    Max Error =   3.3172
# 2025-12-19 16:06:25.867 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0395    RMSE =   0.1971    Max Error =   3.0095
# 2025-12-19 16:06:26.748 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0367    RMSE =   0.1900    Max Error =   2.9366
# 2025-12-19 16:06:27.636 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0343    RMSE =   0.1835    Max Error =   2.8628
# 2025-12-19 16:06:28.515 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0321    RMSE =   0.1776    Max Error =   2.7882
# 2025-12-19 16:06:29.394 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0303    RMSE =   0.1723    Max Error =   2.7129
# 2025-12-19 16:06:30.274 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0286    RMSE =   0.1674    Max Error =   2.6372
# 2025-12-19 16:06:31.154 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0272    RMSE =   0.1631    Max Error =   2.5610
# 2025-12-19 16:06:32.034 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0259    RMSE =   0.1592    Max Error =   2.4846
# 2025-12-19 16:06:32.914 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0248    RMSE =   0.1556    Max Error =   2.4081
# 2025-12-19 16:06:33.793 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0239    RMSE =   0.1525    Max Error =   2.3316
# 2025-12-19 16:06:34.673 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0230    RMSE =   0.1497    Max Error =   2.2553
# 2025-12-19 16:06:35.552 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0223    RMSE =   0.1472    Max Error =   2.1792
# 2025-12-19 16:06:36.430 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0216    RMSE =   0.1449    Max Error =   2.1034
# 2025-12-19 16:06:37.309 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0210    RMSE =   0.1429    Max Error =   2.0282
# 2025-12-19 16:06:38.189 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0205    RMSE =   0.1411    Max Error =   1.9536
# 2025-12-19 16:06:39.069 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0201    RMSE =   0.1395    Max Error =   1.8796
# 2025-12-19 16:06:39.948 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0197    RMSE =   0.1380    Max Error =   1.8065
# 2025-12-19 16:06:40.828 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0193    RMSE =   0.1367    Max Error =   1.7343
# 2025-12-19 16:06:41.707 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0190    RMSE =   0.1356    Max Error =   1.6630
# 2025-12-19 16:06:42.587 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0187    RMSE =   0.1345    Max Error =   1.5928
# 2025-12-19 16:06:43.462 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0185    RMSE =   0.1336    Max Error =   1.5237
# 2025-12-19 16:06:44.342 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0182    RMSE =   0.1328    Max Error =   1.4559
# 2025-12-19 16:06:45.222 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0180    RMSE =   0.1320    Max Error =   1.3894
# 2025-12-19 16:06:46.102 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0178    RMSE =   0.1313    Max Error =   1.3242
# 2025-12-19 16:06:46.980 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0177    RMSE =   0.1307    Max Error =   1.2604
# 2025-12-19 16:06:47.859 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0175    RMSE =   0.1302    Max Error =   1.1981
# 2025-12-19 16:06:48.738 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0174    RMSE =   0.1297    Max Error =   1.1372
# 2025-12-19 16:06:49.617 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0173    RMSE =   0.1292    Max Error =   1.0779
# 2025-12-19 16:06:50.494 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0172    RMSE =   0.1288    Max Error =   1.0202
# 2025-12-19 16:06:51.373 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0171    RMSE =   0.1285    Max Error =   0.9641
# 2025-12-19 16:06:52.252 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0170    RMSE =   0.1281    Max Error =   0.9096
# 2025-12-19 16:06:53.131 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0169    RMSE =   0.1278    Max Error =   0.8567
# 2025-12-19 16:06:54.009 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0169    RMSE =   0.1276    Max Error =   0.8193
# 2025-12-19 16:06:54.888 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0168    RMSE =   0.1273    Max Error =   0.8151
# 2025-12-19 16:06:55.766 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0168    RMSE =   0.1271    Max Error =   0.8157
# 2025-12-19 16:06:56.645 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0167    RMSE =   0.1269    Max Error =   0.8164
# 2025-12-19 16:06:57.527 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0167    RMSE =   0.1268    Max Error =   0.8170
# 2025-12-19 16:06:58.409 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0166    RMSE =   0.1266    Max Error =   0.8176
# 2025-12-19 16:06:59.297 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0166    RMSE =   0.1265    Max Error =   0.8181
# 2025-12-19 16:07:00.179 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0166    RMSE =   0.1263    Max Error =   0.8186
# 2025-12-19 16:07:01.057 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0165    RMSE =   0.1262    Max Error =   0.8191
# 2025-12-19 16:07:01.936 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0165    RMSE =   0.1261    Max Error =   0.8196
# 2025-12-19 16:07:02.815 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0165    RMSE =   0.1260    Max Error =   0.8201
# 2025-12-19 16:07:03.694 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 840: Loss =   0.0165    RMSE =   0.1260    Max Error =   0.8205
# 2025-12-19 16:07:04.572 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 850: Loss =   0.0165    RMSE =   0.1259    Max Error =   0.8209
# 2025-12-19 16:07:05.451 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 860: Loss =   0.0164    RMSE =   0.1258    Max Error =   0.8213
# 2025-12-19 16:07:06.330 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 870: Loss =   0.0164    RMSE =   0.1258    Max Error =   0.8216
# 2025-12-19 16:07:07.208 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 880: Loss =   0.0164    RMSE =   0.1257    Max Error =   0.8219
# 2025-12-19 16:07:08.087 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 890: Loss =   0.0164    RMSE =   0.1257    Max Error =   0.8222
# 2025-12-19 16:07:08.966 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 900: Loss =   0.0164    RMSE =   0.1256    Max Error =   0.8225
# 2025-12-19 16:07:09.845 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 910: Loss =   0.0164    RMSE =   0.1256    Max Error =   0.8228
# 2025-12-19 16:07:10.723 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 920: Loss =   0.0164    RMSE =   0.1256    Max Error =   0.8230
# 2025-12-19 16:07:11.601 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 930: Loss =   0.0164    RMSE =   0.1256    Max Error =   0.8233
# 2025-12-19 16:07:12.480 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 940: Loss =   0.0164    RMSE =   0.1255    Max Error =   0.8235
# 2025-12-19 16:07:13.360 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 950: Loss =   0.0164    RMSE =   0.1255    Max Error =   0.8237
# 2025-12-19 16:07:14.241 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 960: Loss =   0.0164    RMSE =   0.1255    Max Error =   0.8239
# 2025-12-19 16:07:15.119 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 970: Loss =   0.0163    RMSE =   0.1255    Max Error =   0.8240
# 2025-12-19 16:07:15.998 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 980: Loss =   0.0163    RMSE =   0.1255    Max Error =   0.8242
# 2025-12-19 16:07:16.877 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 990: Loss =   0.0163    RMSE =   0.1255    Max Error =   0.8243
# 2025-12-19 16:07:17.759 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1000: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8244
# 2025-12-19 16:07:18.637 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1010: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8246
# 2025-12-19 16:07:19.518 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1020: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8247
# 2025-12-19 16:07:20.399 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1030: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8248
# 2025-12-19 16:07:21.280 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1040: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8248
# 2025-12-19 16:07:22.160 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1050: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8249
# 2025-12-19 16:07:23.043 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1060: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8250
# 2025-12-19 16:07:23.925 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1070: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8251
# 2025-12-19 16:07:24.805 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1080: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8251
# 2025-12-19 16:07:25.687 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1090: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8252
# 2025-12-19 16:07:26.568 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1100: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8252
# 2025-12-19 16:07:27.449 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1110: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8253
# 2025-12-19 16:07:28.331 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1120: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8253
# 2025-12-19 16:07:29.212 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1130: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8254
# 2025-12-19 16:07:30.091 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1140: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8254
# 2025-12-19 16:07:30.972 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1150: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8254
# 2025-12-19 16:07:31.853 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1160: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8255
# 2025-12-19 16:07:32.734 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1170: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8255
# 2025-12-19 16:07:33.613 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1180: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8255
# 2025-12-19 16:07:34.493 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1190: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8255
# 2025-12-19 16:07:35.373 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1200: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8255
# 2025-12-19 16:07:36.253 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1210: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:37.131 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1220: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:38.012 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1230: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:38.891 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1240: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:39.770 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1250: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:40.651 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1260: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:41.531 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1270: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:42.410 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1280: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:43.290 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1290: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:44.170 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1300: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8256
# 2025-12-19 16:07:45.049 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1310: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:45.928 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1320: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:46.809 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1330: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:47.688 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1340: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:48.568 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1350: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:49.447 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1360: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:50.326 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1370: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:51.206 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1380: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:52.087 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1390: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:52.966 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1400: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:53.845 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1410: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:54.726 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1420: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:55.607 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1430: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:56.485 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1440: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:57.364 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1450: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:58.243 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1460: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:07:59.125 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1470: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:08:00.003 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1480: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:08:00.883 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1490: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# 2025-12-19 16:08:01.763 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1500: Loss =   0.0163    RMSE =   0.1254    Max Error =   0.8257
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]

for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    lims = [0, training_results["c6_qm"][training_results["c6_qm"] > 0].max() * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
import re

from openff.toolkit import ForceField
from openff.units import unit as off_unit
from openmm import unit


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
# rmin = rmin2_ref[species_ds] * vol_ratio**(1/3) * 2
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data / off_val, bins=100, kde=True, ax=ax, linewidth=0)

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6^{EMLE} / C_6^{OpenFF-2.0.0}$")
    ax.set_ylabel("Frequency")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
from openff.toolkit import ForceField, Molecule, Topology
from openff.units import unit

ff = ForceField("openff-2.0.0.offxml")
mol = Molecule.from_smiles("C1CCCCC1")
mol.generate_conformers(n_conformers=1)
topology_off = Topology.from_molecules([mol])

xyz_chx = torch.tensor(
    mol.conformers[0].m_as(unit.bohr).astype(np.float32),
    dtype=torch.float32,
    device=device,
).unsqueeze(0)
species_chx = torch.tensor(
    [atom.atomic_number for atom in mol.atoms], dtype=torch.long, device=device
).unsqueeze(0)
q_mol = torch.zeros(xyz_chx.shape[0], device=device, dtype=dtype)

# Get <M_1^2>eff and A_thole for cyclohexane
s, q_core, q_val, A_thole, c6_chx, *_ = emle_base.forward(
    species_chx,
    xyz_chx.to(torch.float32),
    q_mol,
    calc_A_thole=True,
    calc_c6=True,
)

# Get isotropic polarizabilities
alpha_chx = emle_base.get_isotropic_polarizabilities_thole(A_thole)

# Get LJ parameters
c6_chx = 0.5 * c6_chx * alpha_chx
radius = 2.54 * alpha_chx ** (1 / 7)
rmin = 2 * radius
sigma_qm = rmin / (2 ** (1.0 / 6.0))
epsilon_qm = c6_chx / (2 * rmin**6.0)

# Convert units
sigma_qm = sigma_qm / (ANGSTROM_TO_BOHR) * 10
epsilon_qm = epsilon_qm * HARTREE_TO_KJ_MOL / 4.184
q_net = q_core + q_val
c6 = 4 * epsilon_qm * (sigma_qm**6)

# Print table
print(
    f"{'Atom':<6} {'Sigma (A)':<15} {'Epsilon (kcal/mol)':<20} {'Q_core (e)':<10} {'Q_val (e)':<10} {'Q_net (e)':<10}"
)
for i, atom in enumerate(mol.atoms):
    print(
        f"{atom.symbol:<6} {sigma_qm[0, i].item() * 0.1:<15.6f} {epsilon_qm[0, i].item():<20.6f} {q_core[0, i].item():<10.6f} {q_val[0, i].item():<10.6f} {q_net[0, i].item():<10.6f}"
    )
# Out:
# Atom   Sigma (A)       Epsilon (kcal/mol)   Q_core (e) Q_val (e)  Q_net (e)
# C      3.438046        0.099549             4.350801   -4.423770  -0.072969
# C      3.439973        0.099825             4.350801   -4.433394  -0.082593
# C      3.438678        0.099715             4.350801   -4.429653  -0.078852
# C      3.436710        0.099495             4.350801   -4.429975  -0.079174
# C      3.438747        0.099677             4.350801   -4.432225  -0.081424
# C      3.440240        0.099824             4.350801   -4.429902  -0.079101
# H      2.697966        0.015280             1.000000   -0.968298  0.031702
# H      2.697857        0.015415             1.000000   -0.968221  0.031779
# H      2.688442        0.014794             1.000000   -0.954841  0.045159
# H      2.673229        0.014395             1.000000   -0.953087  0.046913
# H      2.704401        0.015425             1.000000   -0.965704  0.034296
# H      2.683044        0.014883             1.000000   -0.961162  0.038838
# H      2.678925        0.014613             1.000000   -0.957034  0.042966
# H      2.696840        0.015096             1.000000   -0.959885  0.040115
# H      2.687638        0.014795             1.000000   -0.956156  0.043844
# H      2.677394        0.014522             1.000000   -0.954789  0.045211
# H      2.690770        0.015224             1.000000   -0.962857  0.037143
# H      2.695504        0.015138             1.000000   -0.963853  0.036147
