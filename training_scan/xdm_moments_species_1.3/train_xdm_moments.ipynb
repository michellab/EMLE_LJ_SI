# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002
# Out:
# /home/joaomorado/micromamba/envs/fes-ml-aev/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")

# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha, m1):
    """XDM C6 coefficient calculation for homoatomic case."""
    return alpha * m1 / 2.0


def c8(alpha, m2):
    """XDM C8 coefficient calculation for homoatomic case."""
    return alpha * m2 * 3 / 2.0


def c10(alpha, m1, m2, m3):
    """XDM C10 coefficient calculation for homoatomic case."""
    return 2.0 * alpha * m3 + 21 / 10 * alpha * m2**2 / (m1 + 1e-16)

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_species_iter2.mat",
    alpha_mode="species",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, _, alpha_unscreened, *_ = emle_base(
    species_ds, xyz_ds, q_mol
)
s = s.detach()
q_core = q_core.detach()
q_val = q_val.detach()
A_thole = A_thole.detach()
alpha = emle_base.get_isotropic_polarizabilities_thole(A_thole)
alpha = alpha.detach() * (species_ds > 0)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, m1_ds)
c8_train = c8(alpha, m2_ds)
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds)

# Setup grid
n = 1000
r_start = 1.3
rij_scale = torch.linspace(r_start, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate dispersion energy
Eij = -(
    c6_train[..., None] / (rij**6 + 1e-16)
    + c8_train[..., None] / (rij**8 + 1e-16)
    + c10_train[..., None] / (rij**10 + 1e-16)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 1000
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, m1_eff).abs()
    Eij_opt = -c6_opt[..., None] / (rij**6 + 1e-16)
    delta = Eij_opt - Eij
    loss = torch.mean(delta[mask] ** 2) / torch.var(Eij[mask])
    loss.backward(retain_graph=True)
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.15507368743419647
# Epoch 50, Loss: 0.007996526546776295
# Epoch 100, Loss: 0.005503723863512278
# Epoch 150, Loss: 0.005440791603177786
# Epoch 200, Loss: 0.0054405913688242435
# Epoch 250, Loss: 0.005440589971840382
# Epoch 300, Loss: 0.005440589971840382
# Epoch 350, Loss: 0.005440589971840382
# Epoch 400, Loss: 0.005440589971840382
# Epoch 450, Loss: 0.005440589971840382
# Epoch 500, Loss: 0.005440589971840382
# Epoch 550, Loss: 0.005440589971840382
# Epoch 600, Loss: 0.005440589971840382
# Epoch 650, Loss: 0.005440589971840382
# Epoch 700, Loss: 0.005440589971840382
# Epoch 750, Loss: 0.005440589971840382
# Epoch 800, Loss: 0.005440589971840382
# Epoch 850, Loss: 0.005440589971840382
# Epoch 900, Loss: 0.005440589971840382
# Epoch 950, Loss: 0.005440589971840382

# %%
# Compute ratios
c6_optimized = c6(alpha, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel(r"$\langle M_1^2 \rangle_{eff}  / \langle M_1^2 \rangle_{XDM}$")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]


def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]


xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %%
species = scipy.io.loadmat("../../emle_models/ligand_patched_species_iter2.mat")
reference = scipy.io.loadmat("../../emle_models/ligand_patched_reference_iter2.mat")

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-2,
    epochs=1500,
    emle_model="../../emle_models/ligand_patched_species_iter2.mat",
    plot_data_filename=plot_data_filename,
    model_filename=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    l2_reg_c6=1e-3,
    alpha_mode="species",
)
# Out:
# 2025-12-19 15:54:25.703 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_species_iter2.mat'
# 2025-12-19 15:54:25.715 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2025-12-19 15:54:26.666 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 10: Loss =  19.5484    RMSE =   4.4214    Max Error =  18.0405
# 2025-12-19 15:54:27.545 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 20: Loss =  16.9088    RMSE =   4.1120    Max Error =  18.1478
# 2025-12-19 15:54:28.426 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 30: Loss =  13.9222    RMSE =   3.7312    Max Error =  18.2787
# 2025-12-19 15:54:29.305 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 40: Loss =  10.8477    RMSE =   3.2936    Max Error =  18.4260
# 2025-12-19 15:54:30.183 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 50: Loss =   8.0550    RMSE =   2.8381    Max Error =  18.5774
# 2025-12-19 15:54:31.059 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 60: Loss =   5.8519    RMSE =   2.4190    Max Error =  18.7177
# 2025-12-19 15:54:31.938 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 70: Loss =   4.2417    RMSE =   2.0595    Max Error =  18.8314
# 2025-12-19 15:54:32.817 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 80: Loss =   3.0549    RMSE =   1.7477    Max Error =  18.9074
# 2025-12-19 15:54:33.699 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 90: Loss =   2.1825    RMSE =   1.4772    Max Error =  18.9442
# 2025-12-19 15:54:34.588 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 100: Loss =   1.5719    RMSE =   1.2536    Max Error =  18.9511
# 2025-12-19 15:54:35.468 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 110: Loss =   1.1537    RMSE =   1.0739    Max Error =  18.9187
# 2025-12-19 15:54:36.343 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 120: Loss =   0.8629    RMSE =   0.9287    Max Error =  18.7487
# 2025-12-19 15:54:37.220 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 130: Loss =   0.6600    RMSE =   0.8121    Max Error =  18.3070
# 2025-12-19 15:54:38.097 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 140: Loss =   0.5193    RMSE =   0.7203    Max Error =  18.0332
# 2025-12-19 15:54:38.986 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 150: Loss =   0.4207    RMSE =   0.6483    Max Error =  17.5653
# 2025-12-19 15:54:39.864 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 160: Loss =   0.3494    RMSE =   0.5907    Max Error =  16.9374
# 2025-12-19 15:54:40.743 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 170: Loss =   0.2958    RMSE =   0.5434    Max Error =  16.2017
# 2025-12-19 15:54:41.622 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 180: Loss =   0.2538    RMSE =   0.5033    Max Error =  15.4076
# 2025-12-19 15:54:42.499 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 190: Loss =   0.2201    RMSE =   0.4686    Max Error =  14.5910
# 2025-12-19 15:54:43.382 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 200: Loss =   0.1923    RMSE =   0.4380    Max Error =  13.7732
# 2025-12-19 15:54:44.261 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 210: Loss =   0.1692    RMSE =   0.4107    Max Error =  12.9649
# 2025-12-19 15:54:45.139 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 220: Loss =   0.1496    RMSE =   0.3861    Max Error =  12.1722
# 2025-12-19 15:54:46.018 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 230: Loss =   0.1328    RMSE =   0.3638    Max Error =  11.3995
# 2025-12-19 15:54:46.896 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 240: Loss =   0.1184    RMSE =   0.3434    Max Error =  10.6512
# 2025-12-19 15:54:47.774 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 250: Loss =   0.1058    RMSE =   0.3245    Max Error =   9.9313
# 2025-12-19 15:54:48.652 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 260: Loss =   0.0948    RMSE =   0.3070    Max Error =   9.2429
# 2025-12-19 15:54:49.531 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.0850    RMSE =   0.2908    Max Error =   8.5880
# 2025-12-19 15:54:50.409 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.0765    RMSE =   0.2756    Max Error =   7.9673
# 2025-12-19 15:54:51.288 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.0688    RMSE =   0.2614    Max Error =   7.3806
# 2025-12-19 15:54:52.167 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.0621    RMSE =   0.2482    Max Error =   6.8271
# 2025-12-19 15:54:53.045 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.0561    RMSE =   0.2358    Max Error =   6.3060
# 2025-12-19 15:54:53.924 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.0508    RMSE =   0.2243    Max Error =   5.8163
# 2025-12-19 15:54:54.803 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.0461    RMSE =   0.2136    Max Error =   5.3570
# 2025-12-19 15:54:55.682 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.0420    RMSE =   0.2036    Max Error =   4.9272
# 2025-12-19 15:54:56.560 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.0383    RMSE =   0.1944    Max Error =   4.5259
# 2025-12-19 15:54:57.439 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.0351    RMSE =   0.1859    Max Error =   4.1521
# 2025-12-19 15:54:58.319 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.0322    RMSE =   0.1781    Max Error =   3.8045
# 2025-12-19 15:54:59.199 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.0297    RMSE =   0.1709    Max Error =   3.4821
# 2025-12-19 15:55:00.078 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.0275    RMSE =   0.1644    Max Error =   3.3000
# 2025-12-19 15:55:00.956 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0256    RMSE =   0.1585    Max Error =   3.2248
# 2025-12-19 15:55:01.843 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0240    RMSE =   0.1532    Max Error =   3.1485
# 2025-12-19 15:55:02.721 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0225    RMSE =   0.1483    Max Error =   3.0712
# 2025-12-19 15:55:03.600 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0212    RMSE =   0.1440    Max Error =   2.9929
# 2025-12-19 15:55:04.479 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0201    RMSE =   0.1401    Max Error =   2.9139
# 2025-12-19 15:55:05.359 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0192    RMSE =   0.1366    Max Error =   2.8343
# 2025-12-19 15:55:06.238 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0183    RMSE =   0.1335    Max Error =   2.7542
# 2025-12-19 15:55:07.137 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0176    RMSE =   0.1307    Max Error =   2.6739
# 2025-12-19 15:55:08.015 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0170    RMSE =   0.1283    Max Error =   2.5934
# 2025-12-19 15:55:08.897 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0164    RMSE =   0.1260    Max Error =   2.5129
# 2025-12-19 15:55:09.779 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0159    RMSE =   0.1241    Max Error =   2.4326
# 2025-12-19 15:55:10.661 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0155    RMSE =   0.1223    Max Error =   2.3526
# 2025-12-19 15:55:11.542 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0151    RMSE =   0.1207    Max Error =   2.2730
# 2025-12-19 15:55:12.422 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0148    RMSE =   0.1193    Max Error =   2.1939
# 2025-12-19 15:55:13.305 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0145    RMSE =   0.1181    Max Error =   2.1156
# 2025-12-19 15:55:14.186 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0142    RMSE =   0.1170    Max Error =   2.0381
# 2025-12-19 15:55:15.072 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0140    RMSE =   0.1159    Max Error =   1.9616
# 2025-12-19 15:55:15.954 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0138    RMSE =   0.1150    Max Error =   1.8862
# 2025-12-19 15:55:16.836 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0136    RMSE =   0.1142    Max Error =   1.8119
# 2025-12-19 15:55:17.720 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0134    RMSE =   0.1135    Max Error =   1.7389
# 2025-12-19 15:55:18.600 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0133    RMSE =   0.1129    Max Error =   1.6673
# 2025-12-19 15:55:19.486 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0131    RMSE =   0.1123    Max Error =   1.5972
# 2025-12-19 15:55:20.375 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0130    RMSE =   0.1118    Max Error =   1.5286
# 2025-12-19 15:55:21.254 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0129    RMSE =   0.1113    Max Error =   1.4617
# 2025-12-19 15:55:22.120 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0128    RMSE =   0.1109    Max Error =   1.3964
# 2025-12-19 15:55:23.422 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0127    RMSE =   0.1105    Max Error =   1.3328
# 2025-12-19 15:55:26.718 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0127    RMSE =   0.1102    Max Error =   1.2711
# 2025-12-19 15:55:30.033 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0126    RMSE =   0.1099    Max Error =   1.2112
# 2025-12-19 15:55:33.356 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0125    RMSE =   0.1096    Max Error =   1.1531
# 2025-12-19 15:55:36.681 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0125    RMSE =   0.1093    Max Error =   1.0969
# 2025-12-19 15:55:39.984 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0124    RMSE =   0.1091    Max Error =   1.0427
# 2025-12-19 15:55:42.007 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0124    RMSE =   0.1089    Max Error =   0.9903
# 2025-12-19 15:55:43.565 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0123    RMSE =   0.1088    Max Error =   0.9399
# 2025-12-19 15:55:45.465 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0123    RMSE =   0.1086    Max Error =   0.8913
# 2025-12-19 15:55:47.387 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0123    RMSE =   0.1085    Max Error =   0.8447
# 2025-12-19 15:55:49.302 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0123    RMSE =   0.1083    Max Error =   0.8000
# 2025-12-19 15:55:51.217 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0122    RMSE =   0.1082    Max Error =   0.7571
# 2025-12-19 15:55:53.132 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0122    RMSE =   0.1081    Max Error =   0.7444
# 2025-12-19 15:55:55.043 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0122    RMSE =   0.1081    Max Error =   0.7449
# 2025-12-19 15:55:56.957 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0122    RMSE =   0.1080    Max Error =   0.7455
# 2025-12-19 15:55:58.875 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0122    RMSE =   0.1079    Max Error =   0.7460
# 2025-12-19 15:56:00.790 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0122    RMSE =   0.1079    Max Error =   0.7465
# 2025-12-19 15:56:02.705 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0121    RMSE =   0.1078    Max Error =   0.7469
# 2025-12-19 15:56:04.620 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0121    RMSE =   0.1078    Max Error =   0.7473
# 2025-12-19 15:56:06.535 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 840: Loss =   0.0121    RMSE =   0.1077    Max Error =   0.7477
# 2025-12-19 15:56:08.451 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 850: Loss =   0.0121    RMSE =   0.1077    Max Error =   0.7481
# 2025-12-19 15:56:10.367 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 860: Loss =   0.0121    RMSE =   0.1077    Max Error =   0.7484
# 2025-12-19 15:56:12.262 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 870: Loss =   0.0121    RMSE =   0.1076    Max Error =   0.7488
# 2025-12-19 15:56:14.159 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 880: Loss =   0.0121    RMSE =   0.1076    Max Error =   0.7491
# 2025-12-19 15:56:16.054 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 890: Loss =   0.0121    RMSE =   0.1076    Max Error =   0.7494
# 2025-12-19 15:56:17.952 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 900: Loss =   0.0121    RMSE =   0.1076    Max Error =   0.7496
# 2025-12-19 15:56:19.827 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 910: Loss =   0.0121    RMSE =   0.1076    Max Error =   0.7499
# 2025-12-19 15:56:21.708 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 920: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7501
# 2025-12-19 15:56:23.589 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 930: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7503
# 2025-12-19 15:56:25.469 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 940: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7505
# 2025-12-19 15:56:27.349 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 950: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7507
# 2025-12-19 15:56:29.225 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 960: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7509
# 2025-12-19 15:56:31.067 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 970: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7511
# 2025-12-19 15:56:32.950 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 980: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7512
# 2025-12-19 15:56:34.831 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 990: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7514
# 2025-12-19 15:56:36.703 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1000: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7515
# 2025-12-19 15:56:38.552 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1010: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7516
# 2025-12-19 15:56:40.462 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1020: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7518
# 2025-12-19 15:56:42.342 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1030: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7519
# 2025-12-19 15:56:44.221 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1040: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7520
# 2025-12-19 15:56:46.106 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1050: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7521
# 2025-12-19 15:56:48.002 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1060: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7521
# 2025-12-19 15:56:49.899 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1070: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7522
# 2025-12-19 15:56:51.796 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1080: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7523
# 2025-12-19 15:56:53.692 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1090: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7524
# 2025-12-19 15:56:55.590 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1100: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7524
# 2025-12-19 15:56:57.485 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1110: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7525
# 2025-12-19 15:56:59.378 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1120: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7525
# 2025-12-19 15:57:01.276 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1130: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7526
# 2025-12-19 15:57:03.172 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1140: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7526
# 2025-12-19 15:57:05.068 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1150: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7527
# 2025-12-19 15:57:06.966 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1160: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7527
# 2025-12-19 15:57:08.862 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1170: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7527
# 2025-12-19 15:57:10.758 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1180: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7528
# 2025-12-19 15:57:12.654 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1190: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7528
# 2025-12-19 15:57:14.549 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1200: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7528
# 2025-12-19 15:57:16.447 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1210: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7529
# 2025-12-19 15:57:18.342 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1220: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7529
# 2025-12-19 15:57:20.238 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1230: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7529
# 2025-12-19 15:57:22.135 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1240: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7529
# 2025-12-19 15:57:24.031 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1250: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7529
# 2025-12-19 15:57:25.928 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1260: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7529
# 2025-12-19 15:57:27.824 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1270: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:29.722 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1280: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:31.618 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1290: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:33.513 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1300: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:35.404 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1310: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:37.305 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1320: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:39.199 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1330: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:41.096 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1340: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:42.992 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1350: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:44.888 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1360: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:46.785 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1370: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7530
# 2025-12-19 15:57:48.682 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1380: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:57:50.580 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1390: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:57:52.452 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1400: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:57:54.330 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1410: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:57:56.211 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1420: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:57:58.090 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1430: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:57:59.993 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1440: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:58:01.890 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1450: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:58:03.785 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1460: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:58:05.656 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1470: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:58:07.536 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1480: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:58:09.434 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1490: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# 2025-12-19 15:58:11.329 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1500: Loss =   0.0121    RMSE =   0.1075    Max Error =   0.7531
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]

for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    lims = [0, training_results["c6_qm"][training_results["c6_qm"] > 0].max() * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
import re

from openff.toolkit import ForceField
from openff.units import unit as off_unit
from openmm import unit


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
# rmin = rmin2_ref[species_ds] * vol_ratio**(1/3) * 2
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data / off_val, bins=100, kde=True, ax=ax, linewidth=0)

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6^{EMLE} / C_6^{OpenFF-2.0.0}$")
    ax.set_ylabel("Frequency")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
from openff.toolkit import ForceField, Molecule, Topology
from openff.units import unit

ff = ForceField("openff-2.0.0.offxml")
mol = Molecule.from_smiles("C1CCCCC1")
mol.generate_conformers(n_conformers=1)
topology_off = Topology.from_molecules([mol])

xyz_chx = torch.tensor(
    mol.conformers[0].m_as(unit.bohr).astype(np.float32),
    dtype=torch.float32,
    device=device,
).unsqueeze(0)
species_chx = torch.tensor(
    [atom.atomic_number for atom in mol.atoms], dtype=torch.long, device=device
).unsqueeze(0)
q_mol = torch.zeros(xyz_chx.shape[0], device=device, dtype=dtype)

# Get <M_1^2>eff and A_thole for cyclohexane
s, q_core, q_val, A_thole, c6_chx, *_ = emle_base.forward(
    species_chx,
    xyz_chx.to(torch.float32),
    q_mol,
    calc_A_thole=True,
    calc_c6=True,
)

# Get isotropic polarizabilities
alpha_chx = emle_base.get_isotropic_polarizabilities_thole(A_thole)

# Get LJ parameters
c6_chx = 0.5 * c6_chx * alpha_chx
radius = 2.54 * alpha_chx ** (1 / 7)
rmin = 2 * radius
sigma_qm = rmin / (2 ** (1.0 / 6.0))
epsilon_qm = c6_chx / (2 * rmin**6.0)

# Convert units
sigma_qm = sigma_qm / (ANGSTROM_TO_BOHR) * 10
epsilon_qm = epsilon_qm * HARTREE_TO_KJ_MOL / 4.184
q_net = q_core + q_val
c6 = 4 * epsilon_qm * (sigma_qm**6)

# Print table
print(
    f"{'Atom':<6} {'Sigma (A)':<15} {'Epsilon (kcal/mol)':<20} {'Q_core (e)':<10} {'Q_val (e)':<10} {'Q_net (e)':<10}"
)
for i, atom in enumerate(mol.atoms):
    print(
        f"{atom.symbol:<6} {sigma_qm[0, i].item() * 0.1:<15.6f} {epsilon_qm[0, i].item():<20.6f} {q_core[0, i].item():<10.6f} {q_val[0, i].item():<10.6f} {q_net[0, i].item():<10.6f}"
    )
# Out:
# Atom   Sigma (A)       Epsilon (kcal/mol)   Q_core (e) Q_val (e)  Q_net (e)
# C      3.438046        0.087512             4.350801   -4.423770  -0.072969
# C      3.439973        0.087720             4.350801   -4.433394  -0.082593
# C      3.438678        0.087624             4.350801   -4.429653  -0.078852
# C      3.436710        0.087417             4.350801   -4.429975  -0.079174
# C      3.438747        0.087585             4.350801   -4.432225  -0.081424
# C      3.440240        0.087742             4.350801   -4.429902  -0.079101
# H      2.697966        0.013990             1.000000   -0.968298  0.031702
# H      2.697857        0.014115             1.000000   -0.968221  0.031779
# H      2.688442        0.013567             1.000000   -0.954841  0.045159
# H      2.673229        0.013206             1.000000   -0.953087  0.046913
# H      2.704401        0.014123             1.000000   -0.965704  0.034296
# H      2.683044        0.013630             1.000000   -0.961162  0.038838
# H      2.678925        0.013405             1.000000   -0.957034  0.042966
# H      2.696840        0.013838             1.000000   -0.959885  0.040115
# H      2.687638        0.013567             1.000000   -0.956156  0.043844
# H      2.677394        0.013324             1.000000   -0.954789  0.045211
# H      2.690770        0.013939             1.000000   -0.962857  0.037143
# H      2.695504        0.013876             1.000000   -0.963853  0.036147
