# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002
# Out:
# /home/joaomorado/micromamba/envs/fes-ml-aev/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")

# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha, m1):
    """XDM C6 coefficient calculation for homoatomic case."""
    return alpha * m1 / 2.0


def c8(alpha, m2):
    """XDM C8 coefficient calculation for homoatomic case."""
    return alpha * m2 * 3 / 2.0


def c10(alpha, m1, m2, m3):
    """XDM C10 coefficient calculation for homoatomic case."""
    return 2.0 * alpha * m3 + 21 / 10 * alpha * m2**2 / (m1 + 1e-16)

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_species_iter2.mat",
    alpha_mode="species",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, _, alpha_unscreened, *_ = emle_base(
    species_ds, xyz_ds, q_mol
)
s = s.detach()
q_core = q_core.detach()
q_val = q_val.detach()
A_thole = A_thole.detach()
alpha = emle_base.get_isotropic_polarizabilities_thole(A_thole)
alpha = alpha.detach() * (species_ds > 0)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, m1_ds)
c8_train = c8(alpha, m2_ds)
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds)

# Setup grid
n = 1000
r_start = 1.0
rij_scale = torch.linspace(r_start, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate dispersion energy
Eij = -(
    c6_train[..., None] / (rij**6 + 1e-16)
    + c8_train[..., None] / (rij**8 + 1e-16)
    + c10_train[..., None] / (rij**10 + 1e-16)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 1000
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, m1_eff).abs()
    Eij_opt = -c6_opt[..., None] / (rij**6 + 1e-16)
    delta = Eij_opt - Eij
    loss = torch.mean(delta[mask] ** 2) / torch.var(Eij[mask])
    loss.backward(retain_graph=True)
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.318244993686676
# Epoch 50, Loss: 0.045663271099328995
# Epoch 100, Loss: 0.018238645046949387
# Epoch 150, Loss: 0.014359012246131897
# Epoch 200, Loss: 0.01320687122642994
# Epoch 250, Loss: 0.012929528020322323
# Epoch 300, Loss: 0.012877540662884712
# Epoch 350, Loss: 0.012869893573224545
# Epoch 400, Loss: 0.01286900881677866
# Epoch 450, Loss: 0.012868928723037243
# Epoch 500, Loss: 0.01286892406642437
# Epoch 550, Loss: 0.012868923135101795
# Epoch 600, Loss: 0.012868923135101795
# Epoch 650, Loss: 0.012868923135101795
# Epoch 700, Loss: 0.012868923135101795
# Epoch 750, Loss: 0.012868923135101795
# Epoch 800, Loss: 0.012868923135101795
# Epoch 850, Loss: 0.012868923135101795
# Epoch 900, Loss: 0.012868923135101795
# Epoch 950, Loss: 0.012868923135101795

# %%
# Compute ratios
c6_optimized = c6(alpha, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel(r"$\langle M_1^2 \rangle_{eff}  / \langle M_1^2 \rangle_{XDM}$")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]


def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]


xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %%
species = scipy.io.loadmat("../../emle_models/ligand_patched_species_iter2.mat")
reference = scipy.io.loadmat("../../emle_models/ligand_patched_reference_iter2.mat")

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-2,
    epochs=1500,
    emle_model="../../emle_models/ligand_patched_species_iter2.mat",
    plot_data_filename=plot_data_filename,
    model_filename=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    l2_reg_c6=1e-3,
    alpha_mode="species",
)
# Out:
# 2025-12-19 15:43:01.168 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_species_iter2.mat'
# 2025-12-19 15:43:01.180 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2025-12-19 15:43:02.133 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 10: Loss =  40.6193    RMSE =   6.3733    Max Error =  25.7752
# 2025-12-19 15:43:03.006 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 20: Loss =  36.6287    RMSE =   6.0522    Max Error =  25.8871
# 2025-12-19 15:43:03.878 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 30: Loss =  32.0367    RMSE =   5.6601    Max Error =  26.0272
# 2025-12-19 15:43:04.750 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 40: Loss =  26.8715    RMSE =   5.1838    Max Error =  26.1859
# 2025-12-19 15:43:05.625 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 50: Loss =  21.5685    RMSE =   4.6442    Max Error =  26.3483
# 2025-12-19 15:43:06.501 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 60: Loss =  16.7157    RMSE =   4.0885    Max Error =  26.4968
# 2025-12-19 15:43:07.375 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 70: Loss =  12.7819    RMSE =   3.5751    Max Error =  26.6132
# 2025-12-19 15:43:08.246 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 80: Loss =   9.7942    RMSE =   3.1295    Max Error =  26.6824
# 2025-12-19 15:43:09.119 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 90: Loss =   7.5092    RMSE =   2.7402    Max Error =  26.6985
# 2025-12-19 15:43:09.993 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 100: Loss =   5.7383    RMSE =   2.3954    Max Error =  26.6733
# 2025-12-19 15:43:10.867 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 110: Loss =   4.3955    RMSE =   2.0964    Max Error =  26.6464
# 2025-12-19 15:43:11.740 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 120: Loss =   3.3922    RMSE =   1.8416    Max Error =  26.6676
# 2025-12-19 15:43:12.613 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 130: Loss =   2.6339    RMSE =   1.6227    Max Error =  26.6977
# 2025-12-19 15:43:13.501 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 140: Loss =   2.0567    RMSE =   1.4339    Max Error =  26.5378
# 2025-12-19 15:43:14.385 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 150: Loss =   1.6235    RMSE =   1.2739    Max Error =  25.9809
# 2025-12-19 15:43:15.261 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 160: Loss =   1.3041    RMSE =   1.1417    Max Error =  25.4673
# 2025-12-19 15:43:16.139 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 170: Loss =   1.0701    RMSE =   1.0341    Max Error =  24.9107
# 2025-12-19 15:43:17.016 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 180: Loss =   0.8969    RMSE =   0.9467    Max Error =  24.1467
# 2025-12-19 15:43:17.891 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 190: Loss =   0.7656    RMSE =   0.8746    Max Error =  23.2341
# 2025-12-19 15:43:18.767 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 200: Loss =   0.6628    RMSE =   0.8137    Max Error =  22.2309
# 2025-12-19 15:43:19.648 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 210: Loss =   0.5799    RMSE =   0.7611    Max Error =  21.1838
# 2025-12-19 15:43:20.523 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 220: Loss =   0.5114    RMSE =   0.7146    Max Error =  20.1241
# 2025-12-19 15:43:21.401 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 230: Loss =   0.4537    RMSE =   0.6730    Max Error =  19.0696
# 2025-12-19 15:43:22.278 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 240: Loss =   0.4045    RMSE =   0.6355    Max Error =  18.0295
# 2025-12-19 15:43:23.157 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 250: Loss =   0.3623    RMSE =   0.6013    Max Error =  17.0087
# 2025-12-19 15:43:24.032 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 260: Loss =   0.3256    RMSE =   0.5700    Max Error =  16.0108
# 2025-12-19 15:43:24.909 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.2935    RMSE =   0.5411    Max Error =  15.0393
# 2025-12-19 15:43:25.786 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.2652    RMSE =   0.5142    Max Error =  14.0979
# 2025-12-19 15:43:26.661 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.2401    RMSE =   0.4892    Max Error =  13.1902
# 2025-12-19 15:43:27.538 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.2177    RMSE =   0.4658    Max Error =  12.3189
# 2025-12-19 15:43:28.414 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.1977    RMSE =   0.4438    Max Error =  11.4860
# 2025-12-19 15:43:29.290 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.1798    RMSE =   0.4232    Max Error =  10.6927
# 2025-12-19 15:43:30.169 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.1637    RMSE =   0.4037    Max Error =   9.9394
# 2025-12-19 15:43:31.046 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.1492    RMSE =   0.3853    Max Error =   9.2261
# 2025-12-19 15:43:31.921 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.1361    RMSE =   0.3680    Max Error =   8.5522
# 2025-12-19 15:43:32.798 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.1244    RMSE =   0.3516    Max Error =   7.9172
# 2025-12-19 15:43:33.673 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.1138    RMSE =   0.3363    Max Error =   7.3201
# 2025-12-19 15:43:34.549 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.1043    RMSE =   0.3218    Max Error =   6.7599
# 2025-12-19 15:43:35.422 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.0958    RMSE =   0.3083    Max Error =   6.2355
# 2025-12-19 15:43:36.299 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0881    RMSE =   0.2956    Max Error =   5.7455
# 2025-12-19 15:43:37.177 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0813    RMSE =   0.2838    Max Error =   5.2888
# 2025-12-19 15:43:38.055 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0752    RMSE =   0.2728    Max Error =   5.1413
# 2025-12-19 15:43:38.930 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0697    RMSE =   0.2626    Max Error =   5.0532
# 2025-12-19 15:43:39.806 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0649    RMSE =   0.2532    Max Error =   4.9629
# 2025-12-19 15:43:40.682 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0606    RMSE =   0.2446    Max Error =   4.8705
# 2025-12-19 15:43:41.558 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0567    RMSE =   0.2366    Max Error =   4.7760
# 2025-12-19 15:43:42.433 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0534    RMSE =   0.2294    Max Error =   4.6797
# 2025-12-19 15:43:43.310 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0504    RMSE =   0.2227    Max Error =   4.5817
# 2025-12-19 15:43:44.187 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0477    RMSE =   0.2167    Max Error =   4.4821
# 2025-12-19 15:43:45.063 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0453    RMSE =   0.2112    Max Error =   4.3811
# 2025-12-19 15:43:45.940 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0433    RMSE =   0.2062    Max Error =   4.2787
# 2025-12-19 15:43:46.825 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0414    RMSE =   0.2017    Max Error =   4.1753
# 2025-12-19 15:43:47.706 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0398    RMSE =   0.1976    Max Error =   4.0710
# 2025-12-19 15:43:48.587 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0383    RMSE =   0.1939    Max Error =   3.9658
# 2025-12-19 15:43:49.467 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0371    RMSE =   0.1906    Max Error =   3.8601
# 2025-12-19 15:43:50.350 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0359    RMSE =   0.1876    Max Error =   3.7539
# 2025-12-19 15:43:51.229 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0349    RMSE =   0.1848    Max Error =   3.6475
# 2025-12-19 15:43:52.110 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0340    RMSE =   0.1823    Max Error =   3.5409
# 2025-12-19 15:43:52.990 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0332    RMSE =   0.1801    Max Error =   3.4345
# 2025-12-19 15:43:53.870 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0324    RMSE =   0.1780    Max Error =   3.3282
# 2025-12-19 15:43:54.751 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0318    RMSE =   0.1762    Max Error =   3.2224
# 2025-12-19 15:43:55.633 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0312    RMSE =   0.1745    Max Error =   3.1172
# 2025-12-19 15:43:56.514 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0307    RMSE =   0.1730    Max Error =   3.0127
# 2025-12-19 15:43:57.394 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0302    RMSE =   0.1716    Max Error =   2.9090
# 2025-12-19 15:43:58.276 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0298    RMSE =   0.1704    Max Error =   2.8064
# 2025-12-19 15:43:59.157 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0294    RMSE =   0.1692    Max Error =   2.7049
# 2025-12-19 15:44:00.037 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0290    RMSE =   0.1682    Max Error =   2.6048
# 2025-12-19 15:44:00.919 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0287    RMSE =   0.1672    Max Error =   2.5060
# 2025-12-19 15:44:01.799 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0284    RMSE =   0.1664    Max Error =   2.4089
# 2025-12-19 15:44:02.679 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0282    RMSE =   0.1656    Max Error =   2.3133
# 2025-12-19 15:44:03.560 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0279    RMSE =   0.1649    Max Error =   2.2196
# 2025-12-19 15:44:04.441 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0277    RMSE =   0.1642    Max Error =   2.1277
# 2025-12-19 15:44:05.323 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0275    RMSE =   0.1636    Max Error =   2.0377
# 2025-12-19 15:44:06.204 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0273    RMSE =   0.1631    Max Error =   1.9498
# 2025-12-19 15:44:07.084 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0272    RMSE =   0.1626    Max Error =   1.8640
# 2025-12-19 15:44:07.963 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0270    RMSE =   0.1621    Max Error =   1.7803
# 2025-12-19 15:44:08.843 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0269    RMSE =   0.1617    Max Error =   1.6989
# 2025-12-19 15:44:09.722 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0268    RMSE =   0.1614    Max Error =   1.6197
# 2025-12-19 15:44:10.604 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0267    RMSE =   0.1611    Max Error =   1.5428
# 2025-12-19 15:44:11.486 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0266    RMSE =   0.1608    Max Error =   1.4683
# 2025-12-19 15:44:12.366 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0265    RMSE =   0.1605    Max Error =   1.3960
# 2025-12-19 15:44:13.246 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0264    RMSE =   0.1602    Max Error =   1.3262
# 2025-12-19 15:44:14.129 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0264    RMSE =   0.1600    Max Error =   1.2587
# 2025-12-19 15:44:15.010 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 840: Loss =   0.0263    RMSE =   0.1598    Max Error =   1.1936
# 2025-12-19 15:44:15.891 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 850: Loss =   0.0262    RMSE =   0.1597    Max Error =   1.1430
# 2025-12-19 15:44:16.772 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 860: Loss =   0.0262    RMSE =   0.1595    Max Error =   1.1413
# 2025-12-19 15:44:17.653 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 870: Loss =   0.0261    RMSE =   0.1594    Max Error =   1.1397
# 2025-12-19 15:44:18.534 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 880: Loss =   0.0261    RMSE =   0.1592    Max Error =   1.1381
# 2025-12-19 15:44:19.419 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 890: Loss =   0.0261    RMSE =   0.1591    Max Error =   1.1367
# 2025-12-19 15:44:20.300 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 900: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1353
# 2025-12-19 15:44:21.181 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 910: Loss =   0.0260    RMSE =   0.1589    Max Error =   1.1340
# 2025-12-19 15:44:22.060 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 920: Loss =   0.0260    RMSE =   0.1588    Max Error =   1.1328
# 2025-12-19 15:44:22.940 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 930: Loss =   0.0260    RMSE =   0.1588    Max Error =   1.1317
# 2025-12-19 15:44:23.821 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 940: Loss =   0.0259    RMSE =   0.1587    Max Error =   1.1306
# 2025-12-19 15:44:24.702 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 950: Loss =   0.0259    RMSE =   0.1586    Max Error =   1.1296
# 2025-12-19 15:44:25.583 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 960: Loss =   0.0259    RMSE =   0.1586    Max Error =   1.1287
# 2025-12-19 15:44:26.465 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 970: Loss =   0.0259    RMSE =   0.1585    Max Error =   1.1278
# 2025-12-19 15:44:27.346 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 980: Loss =   0.0259    RMSE =   0.1585    Max Error =   1.1270
# 2025-12-19 15:44:28.228 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 990: Loss =   0.0259    RMSE =   0.1585    Max Error =   1.1262
# 2025-12-19 15:44:29.107 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1000: Loss =   0.0258    RMSE =   0.1584    Max Error =   1.1255
# 2025-12-19 15:44:29.987 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1010: Loss =   0.0258    RMSE =   0.1584    Max Error =   1.1248
# 2025-12-19 15:44:30.866 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1020: Loss =   0.0258    RMSE =   0.1584    Max Error =   1.1242
# 2025-12-19 15:44:31.746 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1030: Loss =   0.0258    RMSE =   0.1584    Max Error =   1.1236
# 2025-12-19 15:44:32.629 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1040: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1230
# 2025-12-19 15:44:33.511 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1050: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1225
# 2025-12-19 15:44:34.390 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1060: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1220
# 2025-12-19 15:44:35.272 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1070: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1215
# 2025-12-19 15:44:36.153 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1080: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1211
# 2025-12-19 15:44:37.037 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1090: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1207
# 2025-12-19 15:44:37.916 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1100: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1203
# 2025-12-19 15:44:38.795 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1110: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1200
# 2025-12-19 15:44:39.676 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1120: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1196
# 2025-12-19 15:44:40.555 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1130: Loss =   0.0258    RMSE =   0.1583    Max Error =   1.1193
# 2025-12-19 15:44:41.435 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1140: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1191
# 2025-12-19 15:44:42.316 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1150: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1188
# 2025-12-19 15:44:43.196 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1160: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1186
# 2025-12-19 15:44:44.077 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1170: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1183
# 2025-12-19 15:44:44.957 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1180: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1181
# 2025-12-19 15:44:45.836 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1190: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1179
# 2025-12-19 15:44:46.716 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1200: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1177
# 2025-12-19 15:44:47.599 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1210: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1176
# 2025-12-19 15:44:48.480 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1220: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1174
# 2025-12-19 15:44:49.362 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1230: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1173
# 2025-12-19 15:44:50.242 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1240: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1171
# 2025-12-19 15:44:51.125 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1250: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1170
# 2025-12-19 15:44:52.006 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1260: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1169
# 2025-12-19 15:44:52.888 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1270: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1168
# 2025-12-19 15:44:53.769 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1280: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1167
# 2025-12-19 15:44:54.651 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1290: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1166
# 2025-12-19 15:44:55.531 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1300: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1165
# 2025-12-19 15:44:56.412 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1310: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1164
# 2025-12-19 15:44:57.293 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1320: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1164
# 2025-12-19 15:44:58.173 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1330: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1163
# 2025-12-19 15:44:59.054 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1340: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1163
# 2025-12-19 15:44:59.935 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1350: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1162
# 2025-12-19 15:45:00.817 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1360: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1161
# 2025-12-19 15:45:01.699 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1370: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1161
# 2025-12-19 15:45:02.580 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1380: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1161
# 2025-12-19 15:45:03.463 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1390: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1160
# 2025-12-19 15:45:04.347 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1400: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1160
# 2025-12-19 15:45:05.229 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1410: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1159
# 2025-12-19 15:45:06.110 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1420: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1159
# 2025-12-19 15:45:06.991 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1430: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1159
# 2025-12-19 15:45:07.871 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1440: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1159
# 2025-12-19 15:45:08.750 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1450: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1158
# 2025-12-19 15:45:09.631 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1460: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1158
# 2025-12-19 15:45:10.512 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1470: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1158
# 2025-12-19 15:45:11.393 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1480: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1158
# 2025-12-19 15:45:12.276 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1490: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1158
# 2025-12-19 15:45:13.156 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1500: Loss =   0.0258    RMSE =   0.1582    Max Error =   1.1158
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]

for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    lims = [0, training_results["c6_qm"][training_results["c6_qm"] > 0].max() * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
import re

from openff.toolkit import ForceField
from openff.units import unit as off_unit
from openmm import unit


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model=f"ligand_patched_species_iter2_c6_{r_start}.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
# rmin = rmin2_ref[species_ds] * vol_ratio**(1/3) * 2
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data / off_val, bins=100, kde=True, ax=ax, linewidth=0)

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6^{EMLE} / C_6^{OpenFF-2.0.0}$")
    ax.set_ylabel("Frequency")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
from openff.toolkit import ForceField, Molecule, Topology
from openff.units import unit

ff = ForceField("openff-2.0.0.offxml")
mol = Molecule.from_smiles("C1CCCCC1")
mol.generate_conformers(n_conformers=1)
topology_off = Topology.from_molecules([mol])

xyz_chx = torch.tensor(
    mol.conformers[0].m_as(unit.bohr).astype(np.float32),
    dtype=torch.float32,
    device=device,
).unsqueeze(0)
species_chx = torch.tensor(
    [atom.atomic_number for atom in mol.atoms], dtype=torch.long, device=device
).unsqueeze(0)
q_mol = torch.zeros(xyz_chx.shape[0], device=device, dtype=dtype)

# Get <M_1^2>eff and A_thole for cyclohexane
s, q_core, q_val, A_thole, c6_chx, *_ = emle_base.forward(
    species_chx,
    xyz_chx.to(torch.float32),
    q_mol,
    calc_A_thole=True,
    calc_c6=True,
)

# Get isotropic polarizabilities
alpha_chx = emle_base.get_isotropic_polarizabilities_thole(A_thole)

# Get LJ parameters
c6_chx = 0.5 * c6_chx * alpha_chx
radius = 2.54 * alpha_chx ** (1 / 7)
rmin = 2 * radius
sigma_qm = rmin / (2 ** (1.0 / 6.0))
epsilon_qm = c6_chx / (2 * rmin**6.0)

# Convert units
sigma_qm = sigma_qm / (ANGSTROM_TO_BOHR) * 10
epsilon_qm = epsilon_qm * HARTREE_TO_KJ_MOL / 4.184
q_net = q_core + q_val
c6 = 4 * epsilon_qm * (sigma_qm**6)

# Print table
print(
    f"{'Atom':<6} {'Sigma (A)':<15} {'Epsilon (kcal/mol)':<20} {'Q_core (e)':<10} {'Q_val (e)':<10} {'Q_net (e)':<10}"
)
for i, atom in enumerate(mol.atoms):
    print(
        f"{atom.symbol:<6} {sigma_qm[0, i].item() * 0.1:<15.6f} {epsilon_qm[0, i].item():<20.6f} {q_core[0, i].item():<10.6f} {q_val[0, i].item():<10.6f} {q_net[0, i].item():<10.6f}"
    )
# Out:
# Atom   Sigma (A)       Epsilon (kcal/mol)   Q_core (e) Q_val (e)  Q_net (e)
# C      3.438046        0.120596             4.350801   -4.423770  -0.072969
# C      3.439973        0.121003             4.350801   -4.433394  -0.082593
# C      3.438678        0.120906             4.350801   -4.429653  -0.078852
# C      3.436710        0.120642             4.350801   -4.429975  -0.079174
# C      3.438747        0.120834             4.350801   -4.432225  -0.081424
# C      3.440240        0.120982             4.350801   -4.429902  -0.079101
# H      2.697966        0.017552             1.000000   -0.968298  0.031702
# H      2.697857        0.017707             1.000000   -0.968221  0.031779
# H      2.688442        0.016968             1.000000   -0.954841  0.045159
# H      2.673229        0.016550             1.000000   -0.953087  0.046913
# H      2.704401        0.017700             1.000000   -0.965704  0.034296
# H      2.683044        0.017122             1.000000   -0.961162  0.038838
# H      2.678925        0.016810             1.000000   -0.957034  0.042966
# H      2.696840        0.017314             1.000000   -0.959885  0.040115
# H      2.687638        0.016970             1.000000   -0.956156  0.043844
# H      2.677394        0.016698             1.000000   -0.954789  0.045211
# H      2.690770        0.017463             1.000000   -0.962857  0.037143
# H      2.695504        0.017391             1.000000   -0.963853  0.036147
