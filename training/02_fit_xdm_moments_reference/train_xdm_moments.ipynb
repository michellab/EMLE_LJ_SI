# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002
# Out:
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")

# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha_i, alpha_j, m1_i, m1_j):
    """XDM C6 coefficient calculation for heteroatomic case."""
    return (alpha_i * alpha_j * m1_i * m1_j) / (alpha_j * m1_i + alpha_i * m1_j + 1e-16)


def c8(alpha_i, m1_i, m2_i, alpha_j, m1_j, m2_j):
    """XDM C8 coefficient calculation for heteroatomic case."""
    num = alpha_i * alpha_j * (m1_i * m2_j + m2_i * m1_j)
    denom = alpha_j * m1_i + alpha_i * m1_j + 1e-16
    return (3 / 2.0) * (num / denom)


def c10(alpha_i, m1_i, m2_i, m3_i, alpha_j, m1_j, m2_j, m3_j):
    """XDM C10 coefficient calculation for homoatomic case."""
    num_term1 = 2 * (alpha_i * alpha_j) * (m1_i * m3_j + m3_i * m1_j)
    num_term2 = (21 / 5.0) * (alpha_i * alpha_j) * (m2_i * m2_j)
    denom_term1 = alpha_j * m1_i + alpha_i * m1_j + 1e-16
    denom_term2 = alpha_j * m1_i + alpha_i * m1_j + 1e-16
    return (num_term1 / denom_term1) + (num_term2 / denom_term2)


def r_vdw(c6, c8, c10, a1=1.0, a2=0.0):
    """https://doi.org/10.1063/5.0207682"""
    r_crit = (1 / 3.0) * (
        (c8 / (c6 + 1e-16)) ** 0.5
        + (c10 / (c6 + 1e-16)) ** 0.25
        + (c10 / (c8 + 1e-16)) ** 0.5
    )
    return a1 * r_crit + a2

# %% [markdown]
# ### Generate combined bespoke-patched EMLE model
#
# This model uses the patched parameters for the static interactions, and the bespoke ones for the induced interactions.

# %%
patched_model = scipy.io.loadmat("../../emle_models/ligand_patched_species_iter2.mat")
bespoke_model = scipy.io.loadmat("../../emle_models/ligand_bespoke_iter2.mat")

# Substitute bespoke parameters into patched model for the induction part
patched_model["a_Thole"] = bespoke_model["a_Thole"]
patched_model["k_Z"] = bespoke_model["k_Z"]
patched_model["sqrtk_ref"] = bespoke_model["sqrtk_ref"]

# Save the new model
scipy.io.savemat("../../emle_models/ligand_patched_static_only.mat", patched_model)

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_static_only.mat",
    alpha_mode="reference",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, *_ = emle_base(species_ds, xyz_ds, q_mol)
s = s.detach()
q_core = q_core.detach()
q_val = q_val.detach()
A_thole = A_thole.detach()

# EMLE pols
alpha_emle = emle_base.get_isotropic_polarizabilities_thole(A_thole)
alpha_emle = alpha_emle.detach() * (species_ds > 0)
alpha = torch.where(
    torch.isnan(alpha_emle), torch.zeros_like(alpha_emle), alpha_emle
)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, alpha, m1_ds, m1_ds)
c8_train = c8(alpha, m1_ds, m2_ds, alpha, m1_ds, m2_ds) # alpha_i, m1_i, m2_i, alpha_j, m1_j, m2_j
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds, alpha, m1_ds, m2_ds, m3_ds) # (alpha_i, m1_i, m2_i, m3_i, alpha_j, m1_j, m2_j, m3_j)
# Best: {'loss': 12.124160766601562, 'a1': 0.6677393913269043, 'a2': 0.8683804273605347}
r_vdw_train = r_vdw(c6_train, c8_train, c10_train, a1=0.6677, a2=0.8683)[..., None] 

# Setup grid
n = 1000
r_start = 1.0
rij_scale = torch.linspace(r_start, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate dispersion energy
Eij = -(
    c6_train[..., None] / (rij**6 + r_vdw_train**6 + 1e-16)
    + c8_train[..., None] / (rij**8 + r_vdw_train**8 + 1e-16)
    + c10_train[..., None] / (rij**10 + r_vdw_train**10 + 1e-16)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 1000
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, alpha, m1_eff, m1_eff).abs()
    Eij_opt = -c6_opt[..., None] / (rij**6 + 1e-16)
    delta = Eij_opt - Eij
    loss = torch.mean(delta[mask] ** 2) / torch.var(Eij[mask])
    loss.backward(retain_graph=True)
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.30223748087882996
# Epoch 50, Loss: 0.037829287350177765
# Epoch 100, Loss: 0.012471366673707962
# Epoch 150, Loss: 0.00977571215480566
# Epoch 200, Loss: 0.009242890402674675
# Epoch 250, Loss: 0.00916224718093872
# Epoch 300, Loss: 0.009153797291219234
# Epoch 350, Loss: 0.00915318913757801
# Epoch 400, Loss: 0.009153159335255623
# Epoch 450, Loss: 0.009153158403933048
# Epoch 500, Loss: 0.009153158403933048
# Epoch 550, Loss: 0.009153158403933048
# Epoch 600, Loss: 0.009153158403933048
# Epoch 650, Loss: 0.009153158403933048
# Epoch 700, Loss: 0.009153158403933048
# Epoch 750, Loss: 0.009153158403933048
# Epoch 800, Loss: 0.009153158403933048
# Epoch 850, Loss: 0.009153158403933048
# Epoch 900, Loss: 0.009153158403933048
# Epoch 950, Loss: 0.009153158403933048

# %%
# Compute ratios
c6_optimized = c6(alpha, alpha, m1_eff, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

# Save results to numpy file
np.savez("output/optimized_moments.npz", species=species_np, ratios=ratios)

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel(r"$\langle M_1^2 \rangle_{eff}  / \langle M_1^2 \rangle_{XDM}$")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]

def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]

xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-1,
    epochs=1000,
    emle_model="../../emle_models/ligand_patched_static_only.mat",
    plot_data_filename=plot_data_filename,
    model_filename="ligand_patched_static_only_xdm.mat",
    l2_reg_c6=1e-3,
    alpha_mode="reference",
)
# Out:
# 2026-04-01 15:36:38.443 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_static_only.mat'
# 2026-04-01 15:36:38.453 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2026-04-01 15:36:39.477 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 10: Loss =   9.5429    RMSE =   3.0891    Max Error =  24.4542
# 2026-04-01 15:36:40.440 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 20: Loss =   3.5170    RMSE =   1.8752    Max Error =  24.3947
# 2026-04-01 15:36:41.402 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 30: Loss =   1.3436    RMSE =   1.1589    Max Error =  21.6359
# 2026-04-01 15:36:42.363 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 40: Loss =   0.7025    RMSE =   0.8377    Max Error =  17.0797
# 2026-04-01 15:36:43.323 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 50: Loss =   0.3262    RMSE =   0.5705    Max Error =  12.8884
# 2026-04-01 15:36:44.284 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 60: Loss =   0.1559    RMSE =   0.3940    Max Error =   7.9612
# 2026-04-01 15:36:45.248 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 70: Loss =   0.0840    RMSE =   0.2886    Max Error =   4.3857
# 2026-04-01 15:36:46.210 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 80: Loss =   0.0512    RMSE =   0.2246    Max Error =   3.8803
# 2026-04-01 15:36:47.172 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 90: Loss =   0.0364    RMSE =   0.1888    Max Error =   3.2877
# 2026-04-01 15:36:48.138 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 100: Loss =   0.0311    RMSE =   0.1744    Max Error =   2.6553
# 2026-04-01 15:36:49.102 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 110: Loss =   0.0287    RMSE =   0.1672    Max Error =   2.0130
# 2026-04-01 15:36:50.074 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 120: Loss =   0.0273    RMSE =   0.1629    Max Error =   1.4642
# 2026-04-01 15:36:51.041 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 130: Loss =   0.0266    RMSE =   0.1607    Max Error =   1.1235
# 2026-04-01 15:36:52.005 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 140: Loss =   0.0263    RMSE =   0.1598    Max Error =   1.1199
# 2026-04-01 15:36:52.970 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 150: Loss =   0.0261    RMSE =   0.1593    Max Error =   1.1164
# 2026-04-01 15:36:53.935 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 160: Loss =   0.0261    RMSE =   0.1591    Max Error =   1.1073
# 2026-04-01 15:36:54.902 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 170: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1097
# 2026-04-01 15:36:55.867 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 180: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1062
# 2026-04-01 15:36:56.833 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 190: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1058
# 2026-04-01 15:36:57.800 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 200: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:36:58.766 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 210: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1048
# 2026-04-01 15:36:59.733 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 220: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1048
# 2026-04-01 15:37:00.700 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 230: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:01.669 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 240: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1048
# 2026-04-01 15:37:02.635 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 250: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1048
# 2026-04-01 15:37:03.600 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 260: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1048
# 2026-04-01 15:37:04.565 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:05.530 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:06.496 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:07.462 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:08.426 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:09.391 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:10.356 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:11.321 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:12.285 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:13.250 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:14.215 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:15.180 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:16.144 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:17.109 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:18.073 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:19.038 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:20.004 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:20.970 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:21.935 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:22.900 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:23.864 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:24.828 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:25.793 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:26.760 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:27.730 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:28.700 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:29.673 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:30.644 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:31.614 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:32.583 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:33.554 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:34.524 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:35.494 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:36.463 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:37.433 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:38.404 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:39.374 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:40.346 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:41.316 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:42.286 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:43.256 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:44.226 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:45.196 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:46.165 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:47.134 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:48.106 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:49.076 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:50.046 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:51.017 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:51.987 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:52.957 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:53.927 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:54.897 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:55.871 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:56.842 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:57.812 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:58.782 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:37:59.752 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 840: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:00.724 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 850: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:01.695 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 860: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:02.667 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 870: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:03.638 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 880: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:04.609 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 890: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:05.580 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 900: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:06.550 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 910: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:07.519 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 920: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:08.495 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 930: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:09.465 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 940: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:10.436 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 950: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:11.408 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 960: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:12.379 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 970: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:13.350 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 980: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:14.319 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 990: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# 2026-04-01 15:38:15.288 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1000: Loss =   0.0260    RMSE =   0.1590    Max Error =   1.1049
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model="ligand_patched_static_only_xdm.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)

# %%
# Save data to numpy file
np.savez(
    "output/xdm_training_results.npz",
    species_train=species_train.cpu().numpy(),
    m1_ref_train=training_results["c6_qm"],
    m1_pred=training_results["c6_emle"],
    species_val=species_val.cpu().numpy(),
    m1_ref_val=m1_val.cpu().numpy(),
    m1_val=c6_pred_val.detach().cpu().numpy(),
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]


for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    lims = [0, training_results["c6_qm"][training_results["c6_qm"] > 0].max() * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
import re

from openff.toolkit import ForceField
from openff.units import unit as off_unit
from openmm import unit


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model="ligand_patched_static_only_xdm.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, *_ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
# rmin = rmin2_ref[species_ds] * vol_ratio**(1/3) * 2
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig("output/sigma_comparison.pdf", dpi=300, bbox_inches="tight")

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig("output/epsilon_comparison.pdf", dpi=300, bbox_inches="tight")

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig("output/c6_comparison.pdf", dpi=300, bbox_inches="tight")

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data / off_val, bins=100, kde=True, ax=ax, linewidth=0)

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6^{EMLE} / C_6^{OpenFF-2.0.0}$")
    ax.set_ylabel("Frequency")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig("output/c6_ratio_comparison.pdf", dpi=300, bbox_inches="tight")

# %%
from openff.toolkit import ForceField, Molecule, Topology
from openff.units import unit

ff = ForceField("openff-2.0.0.offxml")
mol = Molecule.from_smiles("CCCCCC")
mol.generate_conformers(n_conformers=1)
topology_off = Topology.from_molecules([mol])

xyz_chx = torch.tensor(
    mol.conformers[0].m_as(unit.angstrom).astype(np.float32),
    dtype=torch.float32,
    device=device,
).unsqueeze(0)
species_chx = torch.tensor(
    [atom.atomic_number for atom in mol.atoms], dtype=torch.long, device=device
).unsqueeze(0)
q_mol = torch.zeros(xyz_chx.shape[0], device=device, dtype=dtype)

# Get <M_1^2>eff and A_thole for cyclohexane
s, q_core, q_val, A_thole, c6_chx, *_ = emle_base.forward(
    species_chx,
    xyz_chx.to(torch.float32),
    q_mol,
    calc_A_thole=True,
    calc_c6=True,
)

# Get isotropic polarizabilities
alpha_chx = emle_base.get_isotropic_polarizabilities_thole(A_thole)

# Get LJ parameters
c6_chx = 0.5 * c6_chx * alpha_chx
radius = 2.54 * alpha_chx ** (1 / 7)
rmin = 2 * radius
sigma_qm = rmin / (2 ** (1.0 / 6.0))
epsilon_qm = c6_chx / (2 * rmin**6.0)

# Convert units
sigma_qm = sigma_qm / (ANGSTROM_TO_BOHR) * 10
epsilon_qm = epsilon_qm * HARTREE_TO_KJ_MOL 
q_net = q_core + q_val
c6 = 4 * epsilon_qm * (sigma_qm**6)

# Print table
print(
    f"{'Atom':<6} {'Sigma (A)':<15} {'Epsilon (kcal/mol)':<20} {'Q_core (e)':<10} {'Q_val (e)':<10} {'Q_net (e)':<10}"
)
for i, atom in enumerate(mol.atoms):
    print(
        f"{atom.symbol:<6} {sigma_qm[0, i].item() * 0.1:<15.6f} {epsilon_qm[0, i].item():<20.6f} {q_core[0, i].item():<10.6f} {q_val[0, i].item():<10.6f} {q_net[0, i].item():<10.6f}"
    )
# Out:
# Atom   Sigma (A)       Epsilon (kcal/mol)   Q_core (e) Q_val (e)  Q_net (e)
# C      3.488027        0.718620             4.350801   -4.760574  -0.409773
# C      3.315260        0.552526             4.350801   -4.491092  -0.140291
# C      3.365028        0.574136             4.350801   -4.533875  -0.183074
# C      3.368281        0.572249             4.350801   -4.532043  -0.181242
# C      3.316267        0.557965             4.350801   -4.492680  -0.141879
# C      3.473018        0.711330             4.350801   -4.750230  -0.399429
# H      2.342204        0.070127             1.000000   -0.886918  0.113082
# H      2.392825        0.074247             1.000000   -0.881878  0.118122
# H      2.318359        0.070349             1.000000   -0.875249  0.124751
# H      2.425161        0.068973             1.000000   -0.905570  0.094430
# H      2.437975        0.069439             1.000000   -0.906047  0.093953
# H      2.381062        0.067758             1.000000   -0.904567  0.095433
# H      2.393376        0.068159             1.000000   -0.905879  0.094121
# H      2.398299        0.069254             1.000000   -0.906240  0.093760
# H      2.390710        0.069745             1.000000   -0.902961  0.097039
# H      2.434438        0.069005             1.000000   -0.910581  0.089419
# H      2.418067        0.067428             1.000000   -0.908812  0.091188
# H      2.351623        0.071101             1.000000   -0.888574  0.111426
# H      2.316804        0.069854             1.000000   -0.874369  0.125631
# H      2.397569        0.072732             1.000000   -0.886668  0.113332
