# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002
# Out:
# /home/joaomorado/micromamba/envs/fes-ml-aev/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")
# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha, m1):
    """XDM C6 coefficient calculation for homoatomic case."""
    return alpha * m1 / 2.0


def c8(alpha, m2):
    """XDM C8 coefficient calculation for homoatomic case."""
    return alpha * m2 * 3 / 2.0


def c10(alpha, m1, m2, m3):
    """XDM C10 coefficient calculation for homoatomic case."""
    return 2.0 * alpha * m3 + 21 / 10 * alpha * m2**2 / (m1 + 1e-16)


def r_vdw(c6, c8, c10, a1=1.0, a2=0.0):
    """https://doi.org/10.1063/5.0207682"""
    r_crit = (1 / 3.0) * ((c8 / c6) ** 0.5 + (c10 / c6) ** 0.25 + (c10 / c8) ** 0.5)
    return a1 * r_crit + a2

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_reference_iter2.mat",
    alpha_mode="reference",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, *_ = emle_base(species_ds, xyz_ds, q_mol)
alpha = emle_base.get_isotropic_polarizabilities(A_thole)
alpha = alpha.detach() * (species_ds > 0)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, m1_ds)
c8_train = c8(alpha, m2_ds)
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds)
r_vdw_train = rmin2

# Setup grid
n = 1000
rij_scale = torch.linspace(1.0, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate damped dispersion energy
# Note that C6 term is undamped, while C8 and C10 are damped
Eij = -(
    c6_train[..., None] / (rij**6)
    + c8_train[..., None] / (rij**8 + r_vdw_train[..., None] ** 8)
    + c10_train[..., None] / (rij**10 + r_vdw_train[..., None] ** 10)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 500
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, m1_eff)
    Eij_opt = -c6_opt[..., None] / (rij**6 + 1e-16)
    loss = torch.mean((Eij_opt[mask] - Eij[mask]) ** 2) / torch.var(Eij[mask])
    loss.backward()
    optimizer.step()
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.22233755886554718
# Epoch 50, Loss: 0.012715832330286503
# Epoch 100, Loss: 0.002414475893601775
# Epoch 150, Loss: 0.0015470271464437246
# Epoch 200, Loss: 0.001491590985096991
# Epoch 250, Loss: 0.0014894693158566952
# Epoch 300, Loss: 0.0014894288033246994
# Epoch 350, Loss: 0.001489428337663412
# Epoch 400, Loss: 0.001489428454078734
# Epoch 450, Loss: 0.001489428454078734

# %%
# Compute ratios
c6_optimized = c6(alpha, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel(r"$\langle M_1^2 \rangle_{eff}  / \langle M_1^2 \rangle_{XDM}$")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]


def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]


xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-2,
    epochs=1500,
    emle_model="../../emle_models/ligand_patched_reference_iter2.mat",
    plot_data_filename=plot_data_filename,
    model_filename="ligand_patched_reference_iter2_c6.mat",
    l2_reg_c6=1e-3,
)
# Out:
# 2025-12-01 12:08:18.331 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_reference_iter2.mat'
# 2025-12-01 12:08:18.375 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2025-12-01 12:08:20.349 | INFO     | emle.train._trainer:_train_loop:278 - Epoch
| INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.1528    RMSE =   0.3902    Max Error =  10.6989
# 2025-12-01 12:09:12.123 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.1385    RMSE =   0.3714    Max Error =   9.9738
# 2025-12-01 12:09:14.042 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.1259    RMSE =   0.3540    Max Error =   9.2802
# 2025-12-01 12:09:15.955 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.1146    RMSE =   0.3376    Max Error =   8.6190
# 2025-12-01 12:09:17.867 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.1045    RMSE =   0.3224    Max Error =   7.9906
# 2025-12-01 12:09:19.783 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.0955    RMSE =   0.3081    Max Error =   7.3948
# 2025-12-01 12:09:21.702 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.0875    RMSE =   0.2948    Max Error =   6.8314
# 2025-12-01 12:09:23.618 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.0803    RMSE =   0.2823    Max Error =   6.3003
# 2025-12-01 12:09:25.539 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.0739    RMSE =   0.2707    Max Error =   5.8007
# 2025-12-01 12:09:27.460 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.0681    RMSE =   0.2599    Max Error =   5.3322
# 2025-12-01 12:09:29.374 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.0630    RMSE =   0.2498    Max Error =   4.8941
# 2025-12-01 12:09:31.292 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.0584    RMSE =   0.2405    Max Error =   4.4856
# 2025-12-01 12:09:33.209 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.0544    RMSE =   0.2319    Max Error =   4.1057
# 2025-12-01 12:09:35.129 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0508    RMSE =   0.2240    Max Error =   3.7533
# 2025-12-01 12:09:37.049 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0476    RMSE =   0.2167    Max Error =   3.4273
# 2025-12-01 12:09:38.967 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0447    RMSE =   0.2101    Max Error =   3.3463
# 2025-12-01 12:09:40.887 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0422    RMSE =   0.2041    Max Error =   3.2723
# 2025-12-01 12:09:42.801 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0400    RMSE =   0.1986    Max Error =   3.1970
# 2025-12-01 12:09:44.719 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0381    RMSE =   0.1936    Max Error =   3.1205
# 2025-12-01 12:09:46.637 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0364    RMSE =   0.1891    Max Error =   3.0430
# 2025-12-01 12:09:48.552 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0349    RMSE =   0.1851    Max Error =   2.9644
# 2025-12-01 12:09:50.469 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0335    RMSE =   0.1815    Max Error =   2.8851
# 2025-12-01 12:09:52.387 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0324    RMSE =   0.1782    Max Error =   2.8050
# 2025-12-01 12:09:54.304 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0313    RMSE =   0.1753    Max Error =   2.7244
# 2025-12-01 12:09:56.224 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0304    RMSE =   0.1727    Max Error =   2.6432
# 2025-12-01 12:09:58.141 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0296    RMSE =   0.1703    Max Error =   2.5618
# 2025-12-01 12:10:00.058 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0289    RMSE =   0.1682    Max Error =   2.4802
# 2025-12-01 12:10:01.975 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0283    RMSE =   0.1663    Max Error =   2.3985
# 2025-12-01 12:10:03.894 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0277    RMSE =   0.1646    Max Error =   2.3169
# 2025-12-01 12:10:05.809 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0272    RMSE =   0.1631    Max Error =   2.2354
# 2025-12-01 12:10:07.725 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0267    RMSE =   0.1617    Max Error =   2.1543
# 2025-12-01 12:10:09.643 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0263    RMSE =   0.1605    Max Error =   2.0736
# 2025-12-01 12:10:11.562 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0260    RMSE =   0.1593    Max Error =   1.9935
# 2025-12-01 12:10:13.479 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0257    RMSE =   0.1583    Max Error =   1.9140
# 2025-12-01 12:10:14.588 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0254    RMSE =   0.1574    Max Error =   1.8353
# 2025-12-01 12:10:15.505 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0251    RMSE =   0.1566    Max Error =   1.7574
# 2025-12-01 12:10:16.391 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0249    RMSE =   0.1559    Max Error =   1.6806
# 2025-12-01 12:10:17.267 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0247    RMSE =   0.1552    Max Error =   1.6048
# 2025-12-01 12:10:18.154 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0245    RMSE =   0.1546    Max Error =   1.5302
# 2025-12-01 12:10:19.040 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0243    RMSE =   0.1540    Max Error =   1.4568
# 2025-12-01 12:10:19.926 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0242    RMSE =   0.1535    Max Error =   1.3848
# 2025-12-01 12:10:20.804 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0240    RMSE =   0.1531    Max Error =   1.3142
# 2025-12-01 12:10:21.691 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0239    RMSE =   0.1527    Max Error =   1.2450
# 2025-12-01 12:10:22.579 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0238    RMSE =   0.1523    Max Error =   1.1774
# 2025-12-01 12:10:23.459 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0237    RMSE =   0.1520    Max Error =   1.1417
# 2025-12-01 12:10:24.344 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0236    RMSE =   0.1516    Max Error =   1.1357
# 2025-12-01 12:10:25.234 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0235    RMSE =   0.1514    Max Error =   1.1299
# 2025-12-01 12:10:26.119 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0234    RMSE =   0.1511    Max Error =   1.1244
# 2025-12-01 12:10:27.004 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0234    RMSE =   0.1509    Max Error =   1.1191
# 2025-12-01 12:10:27.891 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0233    RMSE =   0.1507    Max Error =   1.1141
# 2025-12-01 12:10:28.777 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0232    RMSE =   0.1505    Max Error =   1.1094
# 2025-12-01 12:10:29.663 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0232    RMSE =   0.1503    Max Error =   1.1049
# 2025-12-01 12:10:30.547 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0232    RMSE =   0.1502    Max Error =   1.1006
# 2025-12-01 12:10:31.430 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0231    RMSE =   0.1501    Max Error =   1.0965
# 2025-12-01 12:10:32.310 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0231    RMSE =   0.1499    Max Error =   1.0926
# 2025-12-01 12:10:33.192 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0230    RMSE =   0.1498    Max Error =   1.0890
# 2025-12-01 12:10:34.077 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0230    RMSE =   0.1497    Max Error =   1.0856
# 2025-12-01 12:10:34.962 | INFO     | emle.train._trainer:_train_loop:278 - Epoch
Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0370
# 2025-12-01 12:11:12.047 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1260: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0369
# 2025-12-01 12:11:12.930 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1270: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0367
# 2025-12-01 12:11:13.813 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1280: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0366
# 2025-12-01 12:11:14.696 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1290: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0364
# 2025-12-01 12:11:15.577 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1300: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0363
# 2025-12-01 12:11:16.461 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1310: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0362
# 2025-12-01 12:11:17.344 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1320: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0361
# 2025-12-01 12:11:18.226 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1330: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0360
# 2025-12-01 12:11:19.107 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1340: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0359
# 2025-12-01 12:11:19.990 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1350: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0358
# 2025-12-01 12:11:20.867 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1360: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0357
# 2025-12-01 12:11:21.750 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1370: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0357
# 2025-12-01 12:11:22.632 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1380: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0356
# 2025-12-01 12:11:23.515 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1390: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0356
# 2025-12-01 12:11:24.398 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1400: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0355
# 2025-12-01 12:11:25.280 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1410: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0355
# 2025-12-01 12:11:26.163 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1420: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0354
# 2025-12-01 12:11:27.046 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1430: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0354
# 2025-12-01 12:11:27.925 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1440: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0353
# 2025-12-01 12:11:28.802 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1450: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0353
# 2025-12-01 12:11:29.685 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1460: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0353
# 2025-12-01 12:11:30.565 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1470: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0353
# 2025-12-01 12:11:31.448 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1480: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0352
# 2025-12-01 12:11:32.329 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1490: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0352
# 2025-12-01 12:11:33.212 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1500: Loss =   0.0228    RMSE =   0.1490    Max Error =   1.0352
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model="ligand_patched_reference_iter2_c6.mat", dispersion_mode="c6", device=device
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, _ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]

for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    lims = [0, training_results["c6_qm"].max() * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
from openff.toolkit import ForceField
from openmm import unit
from openff.units import unit as off_unit
import re


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model="ligand_patched_reference_iter2_c6.mat", dispersion_mode="c6", device=device
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, _ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()
