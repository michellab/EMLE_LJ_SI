# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import seaborn as sns
import torch
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from emle.models import EMLE
from emle.train import EMLETrainer
from emle.train._utils import pad_to_max

warnings.filterwarnings("ignore")

color_by_z = {1: "grey", 6: "cyan", 7: "blue", 8: "red", 16: "yellow"}
ANGSTROM_TO_BOHR = 1.8897259886
HARTREE_TO_KJ_MOL = 2625.5002

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float32

# %% [markdown]
# ### Load Data

# %%
xdm_data = h5py.File("pyxdm.output.h5", "r")
# Load exchange-hole moments
m1 = xdm_data["summary_moments"][:, :, 0]
m2 = xdm_data["summary_moments"][:, :, 1]
m3 = xdm_data["summary_moments"][:, :, 2]

m1_ds = pad_to_max(m1).to(device=device, dtype=dtype)
m2_ds = pad_to_max(m2).to(device=device, dtype=dtype)
m3_ds = pad_to_max(m3).to(device=device, dtype=dtype)

# Load atomic data
xyz = xdm_data["atoms"][:, :, 1:4] / ANGSTROM_TO_BOHR
species = xdm_data["atoms"][:, :, 0]

# Pad to max number of atoms
xyz_ds = pad_to_max(xyz).to(device=device, dtype=dtype)
species_ds = pad_to_max(species).to(device=device, dtype=torch.long)
dummy_s = torch.zeros(xyz_ds.shape[0], xyz_ds.shape[1], 1).to(
    device=device, dtype=dtype
)
q_mol = torch.zeros(xyz_ds.shape[0]).to(device=device, dtype=dtype)

# %% [markdown]
# ### Generate effective exchange-hole dipole moments

# %%
def c6(alpha, m1):
    """XDM C6 coefficient calculation for homoatomic case."""
    return alpha * m1 / 2.0


def c8(alpha, m2):
    """XDM C8 coefficient calculation for homoatomic case."""
    return alpha * m2 * 3 / 2.0


def c10(alpha, m1, m2, m3):
    """XDM C10 coefficient calculation for homoatomic case."""
    return 2.0 * alpha * m3 + 21 / 10 * alpha * m2**2 / (m1 + 1e-16)


def tang_toennies_damp_c6(rij, s):
    x = rij / s
    fd6 = 1 - torch.exp(-x) * (
        1 + x + x**2 / 2 + x**3 / 6 + x**4 / 24 + x**5 / 120 + x**6 / 720
    )
    return fd6


def tang_toennies_damp_c8(rij, s):
    x = rij / s
    fd8 = 1 - torch.exp(-x) * (
        1
        + x
        + x**2 / 2
        + x**3 / 6
        + x**4 / 24
        + x**5 / 120
        + x**6 / 720
        + x**7 / 5040
        + x**8 / 40320
    )
    return fd8


def tang_toennies_damp_c10(rij, s):
    x = rij / s
    fd10 = 1 - torch.exp(-x) * (
        1
        + x
        + x**2 / 2
        + x**3 / 6
        + x**4 / 24
        + x**5 / 120
        + x**6 / 720
        + x**7 / 5040
        + x**8 / 40320
        + x**9 / 362880
        + x**10 / 3628800
    )
    return fd10

# %%
emle = EMLE(
    model="../../emle_models/ligand_patched_reference_iter2.mat",
    alpha_mode="reference",
    device=device,
)
emle_base = emle._emle_base
s, q_core, q_val, A_thole, *_ = emle_base(species_ds, xyz_ds, q_mol)
alpha = emle_base.get_isotropic_polarizabilities(A_thole)
alpha = alpha.detach() * (species_ds > 0)
rmin2 = 2.54 * alpha ** (1 / 7) * 2

# %%
# Calculate dispersion coefficients
c6_train = c6(alpha, m1_ds)
c8_train = c8(alpha, m2_ds)
c10_train = c10(alpha, m1_ds, m2_ds, m3_ds)

# Setup grid
n = 1000
rij_scale = torch.linspace(1.0, 3.0, n).to(device=device)
rmin_expanded = rmin2.unsqueeze(-1)
rij = rmin_expanded * rij_scale

# Calculate Tang-Toennies damping function
f6_damp = tang_toennies_damp_c6(rij, s.unsqueeze(-1)).detach()
f8_damp = tang_toennies_damp_c8(rij, s.unsqueeze(-1)).detach()
f10_damp = tang_toennies_damp_c10(rij, s.unsqueeze(-1)).detach()

# Calculate damped dispersion energy
Eij = -(
    f6_damp * c6_train[..., None] / (rij**6)
    + f8_damp * c8_train[..., None] / (rij**8)
    + f10_damp * c10_train[..., None] / (rij**10)
)

# %%
# Setup optimization
lr = 0.1
m1_eff = torch.nn.Parameter(m1_ds.clone().detach())
optimizer = torch.optim.Adam([m1_eff], lr=lr)

# Perform optimization
n_epochs = 1000
mask = species_ds > 0
for epoch in range(n_epochs):
    optimizer.zero_grad()
    c6_opt = c6(alpha, m1_eff)
    Eij_opt = -f6_damp * c6_opt[..., None] / (rij**6)
    loss = torch.mean((Eij_opt[mask] - Eij[mask]) ** 2) / torch.var(Eij[mask])
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.3185112774372101
# Epoch 100, Loss: 0.014814041554927826
# Epoch 200, Loss: 0.010135372169315815
# Epoch 300, Loss: 0.009995107538998127
# Epoch 400, Loss: 0.00999310053884983
# Epoch 500, Loss: 0.00999309029430151
# Epoch 600, Loss: 0.00999309029430151
# Epoch 700, Loss: 0.009993089362978935
# Epoch 800, Loss: 0.00999309029430151
# Epoch 900, Loss: 0.00999309029430151

# %%
# Compute ratios
c6_optimized = c6(alpha, m1_eff).detach().cpu().numpy().flatten()
c6_orig = c6_train.cpu().numpy().flatten()
ratios = c6_optimized / c6_orig
species_np = species_ds.cpu().numpy().flatten()

sns.set(style="whitegrid", font_scale=1.2)

# Create one subplot per Z
z_values = sorted(color_by_z.keys())
fig, axes = plt.subplots(1, len(z_values), figsize=(5 * len(z_values), 4), sharey=True)

# If only one Z, axes may not be iterable
if len(z_values) == 1:
    axes = [axes]

for ax, z in zip(axes, z_values):
    mask = species_np == z
    ax.hist(
        ratios[mask],
        bins=40,
        alpha=0.7,
        color=color_by_z[z],
        density=True,
    )
    ax.set_title(f"Z = {z}")
    ax.set_xlabel("C6 Optimized / C6 Original")
    ax.set_ylabel("Density")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create training dataset

# %%
perm = torch.randperm(xyz_ds.shape[0])
n_samples = len(perm)
n_train = int(0.8 * n_samples)
train_idx = perm[:n_train]
val_idx = perm[n_train:]


def split_tensor(t, idx_train, idx_val):
    return t[idx_train], t[idx_val]


xyz_train, xyz_val = split_tensor(xyz_ds, train_idx, val_idx)
species_train, species_val = split_tensor(species_ds, train_idx, val_idx)
m1_train, m1_val = split_tensor(m1_eff.detach(), train_idx, val_idx)
dummy_s_train, dummy_s_val = split_tensor(dummy_s, train_idx, val_idx)

# %% [markdown]
# ### Train <M1> coefficients

# %%
plot_data_filename = "c6_training_data_results.mat"
trainer = EMLETrainer()
trainer.train(
    z=species_train,
    xyz=xyz_train,
    s=dummy_s_train,
    c6=m1_train,
    q_mol=torch.zeros(xyz_train.shape[0]),
    lr_c6=1e-2,
    epochs=1500,
    emle_model="../../emle_models/ligand_patched_reference_iter2.mat",
    plot_data_filename=plot_data_filename,
    model_filename="ligand_patched_reference_iter2_c6_tt.mat",
    l2_reg_c6=1e-3,
)
# Out:
# 2025-12-01 11:58:20.021 | INFO     | emle.train._trainer:train:625 - Loading pre-trained EMLE model from '../../emle_models/ligand_patched_reference_iter2.mat'
# 2025-12-01 11:58:20.035 | INFO     | emle.train._trainer:train:695 - Fitting c6 values...
# 2025-12-01 11:58:20.982 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 10: Loss =  41.2336    RMSE =   6.4213    Max Error =  24.9833
# 2025-12-01 11:58:21.867 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 20: Loss =  37.3042    RMSE =   6.1077    Max Error =  25.0908
# 2025-12-01 11:58:22.753 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 30: Loss =  32.7010    RMSE =   5.7185    Max Error =  25.2225
# 2025-12-01 11:58:23.637 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 40: Loss =  27.5417    RMSE =   5.2480    Max Error =  25.3716
# 2025-12-01 11:58:24.522 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 50: Loss =  22.2285    RMSE =   4.7147    Max Error =  25.5264
# 2025-12-01 11:58:25.405 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 60: Loss =  17.3513    RMSE =   4.1655    Max Error =  25.6718
# 2025-12-01 11:58:26.289 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 70: Loss =  13.3494    RMSE =   3.6536    Max Error =  25.7915
# 2025-12-01 11:58:27.175 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 80: Loss =  10.2290    RMSE =   3.1982    Max Error =  25.8717
# 2025-12-01 11:58:28.059 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 90: Loss =   7.7620    RMSE =   2.7860    Max Error =  25.9058
# 2025-12-01 11:58:28.942 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 100: Loss =   5.8115    RMSE =   2.4106    Max Error =  25.9017
# 2025-12-01 11:58:29.827 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 110: Loss =   4.3363    RMSE =   2.0822    Max Error =  25.8873
# 2025-12-01 11:58:30.713 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 120: Loss =   3.2668    RMSE =   1.8073    Max Error =  25.8966
# 2025-12-01 11:58:31.599 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 130: Loss =   2.5004    RMSE =   1.5811    Max Error =  25.9018
# 2025-12-01 11:58:32.482 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 140: Loss =   1.9470    RMSE =   1.3951    Max Error =  25.7468
# 2025-12-01 11:58:33.369 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 150: Loss =   1.5446    RMSE =   1.2425    Max Error =  25.2397
# 2025-12-01 11:58:34.258 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 160: Loss =   1.2509    RMSE =   1.1182    Max Error =  24.5383
# 2025-12-01 11:58:35.143 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 170: Loss =   1.0350    RMSE =   1.0170    Max Error =  24.1155
# 2025-12-01 11:58:36.028 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 180: Loss =   0.8735    RMSE =   0.9342    Max Error =  23.5091
# 2025-12-01 11:58:36.915 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 190: Loss =   0.7495    RMSE =   0.8654    Max Error =  22.7662
# 2025-12-01 11:58:37.802 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 200: Loss =   0.6515    RMSE =   0.8068    Max Error =  21.9328
# 2025-12-01 11:58:38.689 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 210: Loss =   0.5719    RMSE =   0.7558    Max Error =  21.0452
# 2025-12-01 11:58:39.575 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 220: Loss =   0.5057    RMSE =   0.7107    Max Error =  20.1277
# 2025-12-01 11:58:40.460 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 230: Loss =   0.4499    RMSE =   0.6702    Max Error =  19.1952
# 2025-12-01 11:58:41.343 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 240: Loss =   0.4022    RMSE =   0.6337    Max Error =  18.2573
# 2025-12-01 11:58:42.228 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 250: Loss =   0.3611    RMSE =   0.6003    Max Error =  17.3209
# 2025-12-01 11:58:43.111 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 260: Loss =   0.3253    RMSE =   0.5697    Max Error =  16.3918
# 2025-12-01 11:58:43.996 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 270: Loss =   0.2939    RMSE =   0.5414    Max Error =  15.4759
# 2025-12-01 11:58:44.880 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 280: Loss =   0.2661    RMSE =   0.5152    Max Error =  14.5783
# 2025-12-01 11:58:45.764 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 290: Loss =   0.2416    RMSE =   0.4908    Max Error =  13.7035
# 2025-12-01 11:58:46.647 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 300: Loss =   0.2197    RMSE =   0.4679    Max Error =  12.8550
# 2025-12-01 11:58:47.531 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 310: Loss =   0.2001    RMSE =   0.4465    Max Error =  12.0357
# 2025-12-01 11:58:48.415 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 320: Loss =   0.1826    RMSE =   0.4264    Max Error =  11.2472
# 2025-12-01 11:58:49.299 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 330: Loss =   0.1668    RMSE =   0.4076    Max Error =  10.4911
# 2025-12-01 11:58:50.184 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 340: Loss =   0.1527    RMSE =   0.3898    Max Error =   9.7682
# 2025-12-01 11:58:51.068 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 350: Loss =   0.1400    RMSE =   0.3732    Max Error =   9.0790
# 2025-12-01 11:58:51.951 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 360: Loss =   0.1286    RMSE =   0.3576    Max Error =   8.4240
# 2025-12-01 11:58:52.834 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 370: Loss =   0.1183    RMSE =   0.3429    Max Error =   7.8032
# 2025-12-01 11:58:53.717 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 380: Loss =   0.1091    RMSE =   0.3292    Max Error =   7.2166
# 2025-12-01 11:58:54.602 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 390: Loss =   0.1009    RMSE =   0.3164    Max Error =   6.6639
# 2025-12-01 11:58:55.486 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 400: Loss =   0.0935    RMSE =   0.3045    Max Error =   6.1446
# 2025-12-01 11:58:56.369 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 410: Loss =   0.0868    RMSE =   0.2935    Max Error =   5.6579
# 2025-12-01 11:58:57.253 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 420: Loss =   0.0809    RMSE =   0.2832    Max Error =   5.2032
# 2025-12-01 11:58:58.137 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 430: Loss =   0.0757    RMSE =   0.2738    Max Error =   4.7792
# 2025-12-01 11:58:59.020 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 440: Loss =   0.0710    RMSE =   0.2651    Max Error =   4.5184
# 2025-12-01 11:58:59.904 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 450: Loss =   0.0669    RMSE =   0.2572    Max Error =   4.4501
# 2025-12-01 11:59:00.787 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 460: Loss =   0.0632    RMSE =   0.2499    Max Error =   4.3799
# 2025-12-01 11:59:01.672 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 470: Loss =   0.0599    RMSE =   0.2433    Max Error =   4.3079
# 2025-12-01 11:59:02.555 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 480: Loss =   0.0570    RMSE =   0.2373    Max Error =   4.2340
# 2025-12-01 11:59:03.439 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 490: Loss =   0.0545    RMSE =   0.2318    Max Error =   4.1585
# 2025-12-01 11:59:04.323 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 500: Loss =   0.0522    RMSE =   0.2269    Max Error =   4.0813
# 2025-12-01 11:59:05.206 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 510: Loss =   0.0502    RMSE =   0.2225    Max Error =   4.0026
# 2025-12-01 11:59:06.092 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 520: Loss =   0.0485    RMSE =   0.2185    Max Error =   3.9224
# 2025-12-01 11:59:06.974 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 530: Loss =   0.0469    RMSE =   0.2149    Max Error =   3.8409
# 2025-12-01 11:59:07.857 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 540: Loss =   0.0455    RMSE =   0.2117    Max Error =   3.7582
# 2025-12-01 11:59:08.740 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 550: Loss =   0.0443    RMSE =   0.2088    Max Error =   3.6744
# 2025-12-01 11:59:09.624 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 560: Loss =   0.0432    RMSE =   0.2062    Max Error =   3.5895
# 2025-12-01 11:59:10.508 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 570: Loss =   0.0423    RMSE =   0.2038    Max Error =   3.5038
# 2025-12-01 11:59:11.391 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 580: Loss =   0.0414    RMSE =   0.2017    Max Error =   3.4172
# 2025-12-01 11:59:12.274 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 590: Loss =   0.0406    RMSE =   0.1998    Max Error =   3.3300
# 2025-12-01 11:59:13.158 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 600: Loss =   0.0400    RMSE =   0.1981    Max Error =   3.2422
# 2025-12-01 11:59:14.041 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 610: Loss =   0.0393    RMSE =   0.1965    Max Error =   3.1541
# 2025-12-01 11:59:14.924 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 620: Loss =   0.0388    RMSE =   0.1951    Max Error =   3.0656
# 2025-12-01 11:59:15.807 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 630: Loss =   0.0383    RMSE =   0.1938    Max Error =   2.9769
# 2025-12-01 11:59:16.691 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 640: Loss =   0.0378    RMSE =   0.1927    Max Error =   2.8882
# 2025-12-01 11:59:17.576 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 650: Loss =   0.0374    RMSE =   0.1916    Max Error =   2.7995
# 2025-12-01 11:59:18.458 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 660: Loss =   0.0371    RMSE =   0.1906    Max Error =   2.7111
# 2025-12-01 11:59:19.341 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 670: Loss =   0.0367    RMSE =   0.1897    Max Error =   2.6229
# 2025-12-01 11:59:20.224 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 680: Loss =   0.0364    RMSE =   0.1889    Max Error =   2.5351
# 2025-12-01 11:59:21.106 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 690: Loss =   0.0362    RMSE =   0.1882    Max Error =   2.4479
# 2025-12-01 11:59:21.987 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 700: Loss =   0.0359    RMSE =   0.1875    Max Error =   2.3613
# 2025-12-01 11:59:22.869 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 710: Loss =   0.0357    RMSE =   0.1869    Max Error =   2.2755
# 2025-12-01 11:59:23.755 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 720: Loss =   0.0355    RMSE =   0.1863    Max Error =   2.1905
# 2025-12-01 11:59:24.638 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 730: Loss =   0.0353    RMSE =   0.1858    Max Error =   2.1065
# 2025-12-01 11:59:25.522 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 740: Loss =   0.0351    RMSE =   0.1854    Max Error =   2.0236
# 2025-12-01 11:59:26.405 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 750: Loss =   0.0349    RMSE =   0.1849    Max Error =   1.9417
# 2025-12-01 11:59:27.288 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 760: Loss =   0.0348    RMSE =   0.1845    Max Error =   1.8612
# 2025-12-01 11:59:28.172 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 770: Loss =   0.0346    RMSE =   0.1841    Max Error =   1.7819
# 2025-12-01 11:59:29.055 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 780: Loss =   0.0345    RMSE =   0.1838    Max Error =   1.7040
# 2025-12-01 11:59:29.940 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 790: Loss =   0.0344    RMSE =   0.1835    Max Error =   1.6276
# 2025-12-01 11:59:30.825 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 800: Loss =   0.0343    RMSE =   0.1832    Max Error =   1.5527
# 2025-12-01 11:59:31.709 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 810: Loss =   0.0342    RMSE =   0.1830    Max Error =   1.4793
# 2025-12-01 11:59:32.593 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 820: Loss =   0.0341    RMSE =   0.1827    Max Error =   1.4076
# 2025-12-01 11:59:33.478 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 830: Loss =   0.0340    RMSE =   0.1825    Max Error =   1.3376
# 2025-12-01 11:59:34.362 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 840: Loss =   0.0340    RMSE =   0.1823    Max Error =   1.3185
# 2025-12-01 11:59:35.247 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 850: Loss =   0.0339    RMSE =   0.1821    Max Error =   1.3134
# 2025-12-01 11:59:36.130 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 860: Loss =   0.0338    RMSE =   0.1819    Max Error =   1.3085
# 2025-12-01 11:59:37.014 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 870: Loss =   0.0338    RMSE =   0.1818    Max Error =   1.3039
# 2025-12-01 11:59:37.897 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 880: Loss =   0.0337    RMSE =   0.1817    Max Error =   1.2996
# 2025-12-01 11:59:38.781 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 890: Loss =   0.0337    RMSE =   0.1815    Max Error =   1.2954
# 2025-12-01 11:59:39.664 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 900: Loss =   0.0336    RMSE =   0.1814    Max Error =   1.2915
# 2025-12-01 11:59:40.549 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 910: Loss =   0.0336    RMSE =   0.1813    Max Error =   1.2877
# 2025-12-01 11:59:41.433 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 920: Loss =   0.0336    RMSE =   0.1812    Max Error =   1.2842
# 2025-12-01 11:59:42.317 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 930: Loss =   0.0335    RMSE =   0.1811    Max Error =   1.2808
# 2025-12-01 11:59:43.200 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 940: Loss =   0.0335    RMSE =   0.1811    Max Error =   1.2776
# 2025-12-01 11:59:44.084 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 950: Loss =   0.0335    RMSE =   0.1810    Max Error =   1.2746
# 2025-12-01 11:59:44.967 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 960: Loss =   0.0335    RMSE =   0.1809    Max Error =   1.2717
# 2025-12-01 11:59:45.852 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 970: Loss =   0.0334    RMSE =   0.1809    Max Error =   1.2690
# 2025-12-01 11:59:46.736 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 980: Loss =   0.0334    RMSE =   0.1808    Max Error =   1.2665
# 2025-12-01 11:59:47.621 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 990: Loss =   0.0334    RMSE =   0.1808    Max Error =   1.2640
# 2025-12-01 11:59:48.500 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1000: Loss =   0.0334    RMSE =   0.1807    Max Error =   1.2618
# 2025-12-01 11:59:49.385 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1010: Loss =   0.0334    RMSE =   0.1807    Max Error =   1.2596
# 2025-12-01 11:59:50.268 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1020: Loss =   0.0334    RMSE =   0.1806    Max Error =   1.2576
# 2025-12-01 11:59:51.154 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1030: Loss =   0.0334    RMSE =   0.1806    Max Error =   1.2557
# 2025-12-01 11:59:52.040 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1040: Loss =   0.0333    RMSE =   0.1806    Max Error =   1.2538
# 2025-12-01 11:59:52.924 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1050: Loss =   0.0333    RMSE =   0.1806    Max Error =   1.2521
# 2025-12-01 11:59:53.807 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1060: Loss =   0.0333    RMSE =   0.1805    Max Error =   1.2505
# 2025-12-01 11:59:54.691 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1070: Loss =   0.0333    RMSE =   0.1805    Max Error =   1.2490
# 2025-12-01 11:59:55.578 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1080: Loss =   0.0333    RMSE =   0.1805    Max Error =   1.2476
# 2025-12-01 11:59:56.462 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1090: Loss =   0.0333    RMSE =   0.1805    Max Error =   1.2463
# 2025-12-01 11:59:57.346 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1100: Loss =   0.0333    RMSE =   0.1805    Max Error =   1.2450
# 2025-12-01 11:59:58.231 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1110: Loss =   0.0333    RMSE =   0.1805    Max Error =   1.2438
# 2025-12-01 11:59:59.115 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1120: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2427
# 2025-12-01 11:59:59.999 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1130: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2416
# 2025-12-01 12:00:00.884 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1140: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2407
# 2025-12-01 12:00:01.767 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1150: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2397
# 2025-12-01 12:00:02.651 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1160: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2389
# 2025-12-01 12:00:03.536 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1170: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2381
# 2025-12-01 12:00:04.418 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1180: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2373
# 2025-12-01 12:00:05.301 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1190: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2366
# 2025-12-01 12:00:06.194 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1200: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2359
# 2025-12-01 12:00:07.084 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1210: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2353
# 2025-12-01 12:00:07.969 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1220: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2347
# 2025-12-01 12:00:08.853 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1230: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2341
# 2025-12-01 12:00:09.744 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1240: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2336
# 2025-12-01 12:00:10.635 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1250: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2331
# 2025-12-01 12:00:11.520 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1260: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2327
# 2025-12-01 12:00:12.407 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1270: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2323
# 2025-12-01 12:00:13.292 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1280: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2319
# 2025-12-01 12:00:14.175 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1290: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2315
# 2025-12-01 12:00:15.058 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1300: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2312
# 2025-12-01 12:00:15.942 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1310: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2308
# 2025-12-01 12:00:16.825 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1320: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2305
# 2025-12-01 12:00:17.709 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1330: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2303
# 2025-12-01 12:00:18.591 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1340: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2300
# 2025-12-01 12:00:19.474 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1350: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2298
# 2025-12-01 12:00:20.359 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1360: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2295
# 2025-12-01 12:00:21.243 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1370: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2293
# 2025-12-01 12:00:22.126 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1380: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2291
# 2025-12-01 12:00:23.010 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1390: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2290
# 2025-12-01 12:00:23.896 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1400: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2288
# 2025-12-01 12:00:24.782 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1410: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2286
# 2025-12-01 12:00:25.666 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1420: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2285
# 2025-12-01 12:00:26.550 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1430: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2284
# 2025-12-01 12:00:27.434 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1440: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2282
# 2025-12-01 12:00:28.318 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1450: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2281
# 2025-12-01 12:00:29.200 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1460: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2280
# 2025-12-01 12:00:30.082 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1470: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2279
# 2025-12-01 12:00:30.966 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1480: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2278
# 2025-12-01 12:00:31.850 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1490: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2278
# 2025-12-01 12:00:32.734 | INFO     | emle.train._trainer:_train_loop:278 - Epoch 1500: Loss =   0.0333    RMSE =   0.1804    Max Error =   1.2277
# EMLEBase(
#   (_emle_aev_computer): EMLEAEVComputer(
#     (_aev_computer): AEVComputer()
#   )
# )

# %% [markdown]
# ### Plot results for training dataset

# %%
# Get training results
training_results = scipy.io.loadmat(plot_data_filename)

# Get testing results
emle = EMLE(
    model="ligand_patched_reference_iter2_c6_tt.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
_, _, _, _, c6_pred_val, *_ = emle_base.forward(
    species_val,
    xyz_val.to(torch.float32),
    torch.zeros(xyz_val.shape[0], device=device),
    calc_c6=True,
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.2)
xlabel = r"$\langle M_1^2 \rangle_{eff}^{XDM}$ [Ha.Bohr$^6$]"
ylabel = r"$\langle M_1^2 \rangle_{eff}^{EMLE}$ [Ha.Bohr$^6$]"

datasets = [
    {
        "ax": axes[0],
        "y_true": training_results["c6_qm"],
        "y_pred": training_results["c6_emle"],
        "species": species_train.cpu().numpy(),
        "title": "Training Dataset",
    },
    {
        "ax": axes[1],
        "y_true": m1_val.cpu().detach().numpy(),
        "y_pred": c6_pred_val.cpu().detach().numpy(),
        "species": species_val.cpu().numpy(),
        "title": "Validation Dataset",
    },
]

for data in datasets:
    ax = data["ax"]
    species = data["species"]
    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # Calculate error and correlation metrics
    mask_global = y_true > 0
    rmse = np.sqrt(mean_squared_error(y_true[mask_global], y_pred[mask_global]))
    mae = mean_absolute_error(y_true[mask_global], y_pred[mask_global])
    r2 = r2_score(y_true[mask_global], y_pred[mask_global])
    bias = np.mean(y_pred[mask_global] - y_true[mask_global])

    for z in color_by_z.keys():
        mask = (species == z) & (y_true > 0)
        ax.scatter(
            y_true[mask],
            y_pred[mask],
            alpha=0.7,
            s=1,
            color=color_by_z[z],
            label=f"Z={z}",
        )

    x = training_results["c6_qm"]
    finite_max = x[np.isfinite(x)].max()
    lims = [0, finite_max * 1.1]
    ax.plot(lims, lims, "k--", linewidth=1)
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(data["title"])

    text_metrics = (
        f"RMSE: {rmse:.4f}\nMAE:  {mae:.4f}\nR²:   {r2:.4f}\nBias: {bias:.4f}"
    )
    ax.text(
        0.05,
        0.95,
        text_metrics,
        transform=ax.transAxes,
        verticalalignment="top",
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
    )

    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mapping to OpenFF atom types

# %%
import pickle as pkl
from openff.toolkit import ForceField
from openmm import unit
from openff.units import unit as off_unit
import re


def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r"(\d+)", s)]

# %%
# Load atom types
atom_types = pkl.load(open("atom_types.pkl", "rb"))

# Get OpenFF vdW parameters
force_field = ForceField("openff-2.0.0.offxml")
vdw_handler = force_field.get_parameter_handler("vdW")
off_vdw_params = {
    param.id: {
        "sigma": param.sigma.to_openmm().value_in_unit(unit.nanometer),
        "epsilon": param.epsilon.to_openmm().value_in_unit(unit.kilojoule_per_mole),
        "smirks": param.smirks,
    }
    for param in vdw_handler.parameters
}

# %%
# Get <M_1^2>eff for the complete dataset
emle = EMLE(
    model="ligand_patched_reference_iter2_c6_tt.mat",
    dispersion_mode="c6",
    device=device,
)
emle_base = emle._emle_base
a, b, c, d, c6_pred_val, _ = emle_base.forward(
    species_ds,
    xyz_ds.to(torch.float32),
    torch.zeros(xyz_ds.shape[0], device=device),
    calc_A_thole=True,
    calc_c6=True,
)
# Convert to LJ parameters
c6 = 0.5 * c6_pred_val * alpha
rmin = 2 * (2.54 * alpha ** (1 / 7))
sigma = rmin / (2 ** (1 / 6))
epsilon = c6 / (4 * sigma**6)

# Convert units
sigma /= ANGSTROM_TO_BOHR * 10
epsilon *= HARTREE_TO_KJ_MOL

# %%
# Map from predicted LJ parameters to OpenFF vdW parameters
emle_lj = {param_id: {"sigma": [], "epsilon": []} for param_id in off_vdw_params.keys()}
for i, mol in enumerate(atom_types):
    for j, at in enumerate(mol):
        emle_lj[at]["sigma"].append(sigma[i][j].item())
        emle_lj[at]["epsilon"].append(epsilon[i][j].item())

# Discard empty entries
emle_lj = {k: v for k, v in emle_lj.items() if v["sigma"] and v["epsilon"]}

# Calculate mean values for each parameter
for param_id, values in emle_lj.items():
    emle_lj[param_id]["sigma_mean"] = np.mean(values["sigma"])
    emle_lj[param_id]["epsilon_mean"] = np.mean(values["epsilon"])
    emle_lj[param_id]["smirks"] = off_vdw_params[param_id]["smirks"]

# %%
# Save OpenFF force field
for param in force_field.get_parameter_handler("vdW").parameters:
    if param.id not in emle_lj:
        continue
    param.sigma = emle_lj[param.id]["sigma_mean"] * off_unit.nanometer
    param.epsilon = emle_lj[param.id]["epsilon_mean"] * off_unit.kilojoules_per_mole

force_field.to_file("openff-2.0.0-emle.offxml")

# %% [markdown]
# ### Plot distributons of XDM-based LJ parameters

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["sigma"]
    mean_val = emle_lj[at]["sigma_mean"]
    off_val = off_vdw_params[at]["sigma"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\sigma$ [nm]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = emle_lj[at]["epsilon"]
    mean_val = emle_lj[at]["epsilon_mean"]
    off_val = off_vdw_params[at]["epsilon"]

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$\epsilon$ [kJ.mol$^{-1}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()

# %%
off_types = sorted(emle_lj.keys(), key=natural_key)
n = len(off_types)
cols = 4
rows = int(np.ceil(n / cols))
fig, axes = plt.subplots(rows, cols, figsize=(16, 4 * rows))
axes = axes.flatten()

for ax, at in zip(axes, off_types):
    data = (
        4
        * np.array(emle_lj[at]["epsilon"])
        * (np.array(emle_lj[at]["sigma"]) * 10) ** 6
    )
    mean_val = data.mean()
    off_val = (
        4
        * np.array(off_vdw_params[at]["epsilon"])
        * (np.array(off_vdw_params[at]["sigma"]) * 10) ** 6
    )

    sns.histplot(data, bins=100, kde=True, ax=ax, linewidth=0)
    ax.axvline(mean_val, color="b", linestyle="dashed", linewidth=2, label="Mean")
    ax.axvline(
        off_val, color="r", linestyle="dashed", linewidth=2, label="OpenFF-2.0.0"
    )

    ax.set_title(f"{at} ({emle_lj[at]['smirks']})", fontsize=10)
    ax.set_xlabel(r"$C_6$ [kJ.mol$^{-1}\AA^{6}$]")
    ax.set_ylabel("Frequency")
    ax.legend(loc="upper center")

for ax in axes[n:]:
    ax.set_visible(False)

plt.tight_layout()
